# %% [markdown]
# # <font color="#0b486b">  FIT3181: Deep Learning (2024) - Assignment 2 (Transformers)</font>
# ***
# *CE/Lecturer (Clayton):*  **Dr Trung Le** | trunglm@monash.edu <br/>
# *Lecturer (Clayton):* **Prof Dinh Phung** | dinh.phung@monash.edu <br/>
# *Lecturer (Malaysia):*  **Dr Arghya Pal** | arghya.pal@monash.edu <br/>
# *Lecturer (Malaysia):*  **Dr Lim Chern Hong** | lim.chernhong@monash.edu <br/>  <br/>
# *Head Tutor 3181:*  **Miss Vy Vo** |  \[v.vo@monash.edu \] <br/>
# *Head Tutor 5215:*  **Dr Van Nguyen** |  \[van.nguyen1@monash.edu \]
#
# <br/> <br/>
# Faculty of Information Technology, Monash University, Australia
# ***

# %% [markdown]
# # <font color="#0b486b">  Student Information</font>
# ***
# Surname: **Beh**  <br/>
# Firstname: **Hanyu**    <br/>
# Student ID: **33607265**    <br/>
# Email: **hbeh0003@student.monash.edu**    <br/>
# Your tutorial time: **Thursday 12pm**    <br/>
# ***

# %% [markdown]
# # <font color="0b486b">Assignment 2 – Deep Learning for Sequential Data</font>
# ### Due: <font color="red">11:55pm Sunday, 27 October 2024</font> (FIT3181)
#
# #### <font color="red">Important note:</font> This is an **individual** assignment. It contributes **15%** to your final mark. Read the assignment instructions carefully.

# %% [markdown]
# ## <font color="#0b486b">Assignment 2's Organization</font>
# This assignment 2 has two (2) sections:
# - Section 1: Fundamentals of RNNs (10 marks).
# - Section 2: Deep Learning for Sequential Data (90 marks). This section is further divided into 4 parts.
#
# The assignment 2 is organized in three (3) notebooks.
# - Notebook 1 ([link](https://colab.research.google.com/drive/1Rm2wWOJCjilpVf4T6RJZFtkjRULuTo0g?usp=sharing)) [Total: 30 marks] includes Section 1 as well as Part 1 and Part 2 of Section 2.
# - Notebook 2 ([link](https://colab.research.google.com/drive/19-WnvLH24yUZ_eih3_8P_Fjn8cM8X2Gz?usp=sharing)) [Total: 40 marks] includes Part 3 of Section 2.
# - Notebook 3 (this notebook) [Total: 30 marks] includes Part 4 of Section 2.

# %% [markdown]
# ## <font color="#0b486b">What to submit</font>
#
# This assignment is to be completed individually and submitted to Moodle unit site. **By the due date, you are required to submit one  <font color="red; font-weight:bold">single zip file, named xxx_assignment02_solution.zip</font> where `xxx` is your student ID, to the corresponding Assignment (Dropbox) in Moodle**. You can use Google Colab to do Assignment 2 but you need to save it to an `*.ipynb` file to submit to the unit Moodle.
#
# **More importantly, if you use Google Colab to do this assignment, you need to first make a copy of this notebook on your Google drive**.

# %% [markdown]
# ***For example, if your student ID is <font color="red; font-weight:bold">12356</font>, then gather all of your assignment solutions to a folder, create a zip file named <font color="red; font-weight:bold">123456_assignment02_solution.zip</font> and submit this file.***

# %% [markdown]
# Within this zip folder, you **must** submit the following files <u>for each part</u>:
# 1.	**`FIT3181_DeepLearning_Assignment2_Official[Main].ipynb`**:  this is your Python notebook solution source file.
# 1.	**`FIT3181_DeepLearning_Assignment2_Official[Main].html`**: this is the output of your Python notebook solution *exported* in HTML format.
# 1. **`FIT3181_DeepLearning_Assignment2_Official[RNNs].ipynb`**
# 1. **`FIT3181_DeepLearning_Assignment2_Official[RNNs].html`**
# 1. **`FIT3181_DeepLearning_Assignment2_Official[Transformers].ipynb`**
# 1. **`FIT3181_DeepLearning_Assignment2_Official[Transformers].html`**
# 1.	Any **extra files or folder** needed to complete your assignment (e.g., images used in your answers).

# %% [markdown]
# ## Section 2: Deep Learning for Sequential Data

# %% [markdown]
# ### <font color="#0b486b">Set random seeds</font>

# %% [markdown]
# We need to install the package datasets for creating BERT datasets.

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.0.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (16.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.15.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading datasets-3.0.2-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 16.3 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.3 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.1 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.0.2 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %% [markdown]
# We start with importing PyTorch and NumPy and setting random seeds for PyTorch and NumPy. You can use any seeds you prefer.

# %%
import os
import torch
import random
import requests
import pandas as pd
import numpy as np
import torch.nn as nn
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
from transformers import BertTokenizer
import os
from six.moves.urllib.request import urlretrieve
from sklearn import preprocessing
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
def seed_all(seed=1029):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
seed_all(seed=1234)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## <font color="#0b486b">Download and preprocess the data</font>
#
# <div style="text-align: right"><font color="red; font-weight:bold"><span></div>

# %% [markdown]
# The dataset we use for this assignment is a question classification dataset for which the training set consists of $5,500$ questions belonging to 6 coarse question categories including:
# - abbreviation (ABBR),
# - entity (ENTY),
# - description (DESC),
# - human (HUM),
# - location (LOC) and
# - numeric (NUM).
#
# In this assignment, we will utilize a subset of this dataset, containing $2,000$ questions for training and validation. We will use 80% of those 2000 questions for trainning and the rest for validation.

# %% [markdown]
# Preprocessing data is a crucial initial step in any machine learning or deep learning project. The *TextDataManager* class simplifies the process by providing functionalities to download and preprocess data specifically designed for the subsequent questions in this assignment. It is highly recommended to gain a comprehensive understanding of the class's functionality by **carefully reading** the content provided in the *TextDataManager* class before proceeding to answer the questions.

# %%
class DataManager:
    """
    This class manages and preprocesses a simple text dataset for a sentence classification task.

    Attributes:
        verbose (bool): Controls verbosity for printing information during data processing.
        max_sentence_len (int): The maximum length of a sentence in the dataset.
        str_questions (list): A list to store the string representations of the questions in the dataset.
        str_labels (list): A list to store the string representations of the labels in the dataset.
        numeral_labels (list): A list to store the numerical representations of the labels in the dataset.
        maxlen (int): Maximum length for padding sequences. Sequences longer than this length will be truncated,
            and sequences shorter than this length will be padded with zeros. Defaults to 50.
        numeral_data (list): A list to store the numerical representations of the questions in the dataset.
        random_state (int): Seed value for random number generation to ensure reproducibility.
            Set this value to a specific integer to reproduce the same random sequence every time. Defaults to 6789.
        random (np.random.RandomState): Random number generator object initialized with the given random_state.
            It is used for various random operations in the class.

    Methods:
        maybe_download(dir_name, file_name, url, verbose=True):
            Downloads a file from a given URL if it does not exist in the specified directory.
            The directory and file are created if they do not exist.

        read_data(dir_name, file_names):
            Reads data from files in a directory, preprocesses it, and computes the maximum sentence length.
            Each file is expected to contain rows in the format "<label>:<question>".
            The labels and questions are stored as string representations.

        manipulate_data():
            Performs data manipulation by tokenizing, numericalizing, and padding the text data.
            The questions are tokenized and converted into numerical sequences using a tokenizer.
            The sequences are padded or truncated to the maximum sequence length.

        train_valid_test_split(train_ratio=0.9):
            Splits the data into training, validation, and test sets based on a given ratio.
            The data is randomly shuffled, and the specified ratio is used to determine the size of the training set.
            The string questions, numerical data, and numerical labels are split accordingly.
            TensorFlow `Dataset` objects are created for the training and validation sets.


    """

    def __init__(self, verbose=True, random_state=6789):
        self.verbose = verbose
        self.max_sentence_len = 0
        self.str_questions = list()
        self.str_labels = list()
        self.numeral_labels = list()
        self.numeral_data = list()
        self.random_state = random_state
        self.random = np.random.RandomState(random_state)

    @staticmethod
    def maybe_download(dir_name, file_name, url, verbose=True):
        if not os.path.exists(dir_name):
            os.mkdir(dir_name)
        if not os.path.exists(os.path.join(dir_name, file_name)):
            urlretrieve(url + file_name, os.path.join(dir_name, file_name))
        if verbose:
            print("Downloaded successfully {}".format(file_name))

    def read_data(self, dir_name, file_names):
        self.str_questions = list()
        self.str_labels = list()
        for file_name in file_names:
            file_path= os.path.join(dir_name, file_name)
            with open(file_path, "r", encoding="latin-1") as f:
                for row in f:
                    row_str = row.split(":")
                    label, question = row_str[0], row_str[1]
                    question = question.lower()
                    self.str_labels.append(label)
                    self.str_questions.append(question[0:-1])
                    if self.max_sentence_len < len(self.str_questions[-1]):
                        self.max_sentence_len = len(self.str_questions[-1])

        # turns labels into numbers
        le = preprocessing.LabelEncoder()
        le.fit(self.str_labels)
        self.numeral_labels = np.array(le.transform(self.str_labels))
        self.str_classes = le.classes_
        self.num_classes = len(self.str_classes)
        if self.verbose:
            print("\nSample questions and corresponding labels... \n")
            print(self.str_questions[0:5])
            print(self.str_labels[0:5])

    def manipulate_data(self):
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
        vocab = self.tokenizer.get_vocab()
        self.word2idx = {w: i for i, w in enumerate(vocab)}
        self.idx2word = {i:w for w,i in self.word2idx.items()}
        self.vocab_size = len(self.word2idx)

        token_ids = []
        num_seqs = []
        for text in self.str_questions:  # iterate over the list of text
          text_seqs = self.tokenizer.tokenize(str(text))  # tokenize each text individually
          # Convert tokens to IDs
          token_ids = self.tokenizer.convert_tokens_to_ids(text_seqs)
          # Convert token IDs to a tensor of indices using your word2idx mapping
          seq_tensor = torch.LongTensor(token_ids)
          num_seqs.append(seq_tensor)  # append the tensor for each sequence

        # Pad the sequences and create a tensor
        if num_seqs:
          self.numeral_data = pad_sequence(num_seqs, batch_first=True)  # Pads to max length of the sequences
          self.num_sentences, self.max_seq_len = self.numeral_data.shape

    def train_valid_test_split(self, train_ratio=0.8, test_ratio = 0.1):
        train_size = int(self.num_sentences*train_ratio) +1
        test_size = int(self.num_sentences*test_ratio) +1
        valid_size = self.num_sentences - (train_size + test_size)
        data_indices = list(range(self.num_sentences))
        random.shuffle(data_indices)
        self.train_str_questions = [self.str_questions[i] for i in data_indices[:train_size]]
        self.train_numeral_labels = self.numeral_labels[data_indices[:train_size]]
        train_set_data = self.numeral_data[data_indices[:train_size]]
        train_set_labels = self.numeral_labels[data_indices[:train_size]]
        train_set_labels = torch.from_numpy(train_set_labels)
        train_set = torch.utils.data.TensorDataset(train_set_data, train_set_labels)
        self.test_str_questions = [self.str_questions[i] for i in data_indices[-test_size:]]
        self.test_numeral_labels = self.numeral_labels[data_indices[-test_size:]]
        test_set_data = self.numeral_data[data_indices[-test_size:]]
        test_set_labels = self.numeral_labels[data_indices[-test_size:]]
        test_set_labels = torch.from_numpy(test_set_labels)
        test_set = torch.utils.data.TensorDataset(test_set_data, test_set_labels)
        self.valid_str_questions = [self.str_questions[i] for i in data_indices[train_size:-test_size]]
        self.valid_numeral_labels = self.numeral_labels[data_indices[train_size:-test_size]]
        valid_set_data = self.numeral_data[data_indices[train_size:-test_size]]
        valid_set_labels = self.numeral_labels[data_indices[train_size:-test_size]]
        valid_set_labels = torch.from_numpy(valid_set_labels)
        valid_set = torch.utils.data.TensorDataset(valid_set_data, valid_set_labels)
        self.train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
        self.test_loader = DataLoader(test_set, batch_size=64, shuffle=False)
        self.valid_loader = DataLoader(valid_set, batch_size=64, shuffle=False)

# %%
print('Loading data...')
DataManager.maybe_download("data", "train_2000.label", "http://cogcomp.org/Data/QA/QC/")

dm = DataManager()
dm.read_data("data/", ["train_2000.label"])
# Out:
# Loading data...
# Downloaded successfully train_2000.label
#
# Sample questions and corresponding labels...
#
# ['manner how did serfdom develop in and then leave russia ?', 'cremat what films featured the character popeye doyle ?', "manner how can i find a list of celebrities ' real names ?", 'animal what fowl grabs the spotlight after the chinese year of the monkey ?', 'exp what is the full form of .com ?']
# ['DESC', 'ENTY', 'DESC', 'ENTY', 'ABBR']

# %%
dm.manipulate_data()
dm.train_valid_test_split(train_ratio=0.8, test_ratio = 0.1)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
for x, y in dm.train_loader:
    print(x.shape, y.shape)
    break
# Out:
# torch.Size([64, 36]) torch.Size([64])

# %% [markdown]
# We now declare the `BaseTrainer` class, which will be used later to train the subsequent deep learning models for text data.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class BaseTrainer:
    def __init__(self, model, criterion, optimizer, train_loader, val_loader):
        self.model = model
        self.criterion = criterion  #the loss function
        self.optimizer = optimizer  #the optimizer
        self.train_loader = train_loader  #the train loader
        self.val_loader = val_loader  #the valid loader

    #the function to train the model in many epochs
    def fit(self, num_epochs):
        self.num_batches = len(self.train_loader)

        for epoch in range(num_epochs):
            print(f'Epoch {epoch + 1}/{num_epochs}')
            train_loss, train_accuracy = self.train_one_epoch()
            val_loss, val_accuracy = self.validate_one_epoch()
            print(
                f'{self.num_batches}/{self.num_batches} - train_loss: {train_loss:.4f} - train_accuracy: {train_accuracy*100:.4f}% \
                - val_loss: {val_loss:.4f} - val_accuracy: {val_accuracy*100:.4f}%')

    #train in one epoch, return the train_acc, train_loss
    def train_one_epoch(self):
        self.model.train()
        running_loss, correct, total = 0.0, 0, 0
        for i, data in enumerate(self.train_loader):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            self.optimizer.zero_grad()
            outputs = self.model(inputs)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        train_accuracy = correct / total
        train_loss = running_loss / self.num_batches
        return train_loss, train_accuracy

    #evaluate on a loader and return the loss and accuracy
    def evaluate(self, loader):
        self.model.eval()
        loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for data in loader:
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = self.model(inputs)
                loss = self.criterion(outputs, labels)
                loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = correct / total
        loss = loss / len(self.val_loader)
        return loss, accuracy

    #return the val_acc, val_loss, be called at the end of each epoch
    def validate_one_epoch(self):
      val_loss, val_accuracy = self.evaluate(self.val_loader)
      return val_loss, val_accuracy

# %% [markdown]
# ## <font color="#0b486b">Part 4: Transformer-based models for sequence modeling and neural embedding</font>
#
# <div style="text-align: right"><font color="red; font-weight:bold">[Total marks for this part: 30 marks]<span></div>

# %% [markdown]
# #### <font color="red">**Question 4.1**</font>
#
# **Implement the multi-head attention module of the Transformer for the text classification problem. The provided code is from our tutorial. In this part, we only use the output of the Transformer encoder for the classification task. For further information on the Transformer model, refer to [this paper](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf).**
#
# <div style="text-align: right"><font color="red; font-weight:bold">[Total marks for this part: 10 marks]<span></div>

# %% [markdown]
# Below is the code of `MultiHeadSelfAttention`, `PositionWiseFeedForward`, `PositionalEncoding`, and `EncoderLayer`.

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super(MultiHeadAttention, self).__init__()
        # Ensure that the model dimension (d_model) is divisible by the number of heads
        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"

        # Initialize dimensions
        self.d_model = d_model # Model's dimension
        self.num_heads = num_heads # Number of attention heads
        self.d_k = d_model // num_heads # Dimension of each head's key, query, and value

        # Linear layers for transforming inputs
        self.W_q = nn.Linear(d_model, d_model) # Query transformation
        self.W_k = nn.Linear(d_model, d_model) # Key transformation
        self.W_v = nn.Linear(d_model, d_model) # Value transformation
        self.W_o = nn.Linear(d_model, d_model) # Output transformation

    def scaled_dot_product_attention(self, Q, K, V):
        # Calculate attention scores
        attn_scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)

        # Apply mask if provided (useful for preventing attention to certain parts like padding)
        #if mask is not None:
            #attn_scores = attn_scores.masked_fill(mask == 0, -1e9)

        # Softmax is applied to obtain attention probabilities
        attn_probs = torch.softmax(attn_scores, dim=-1)

        # Multiply by values to obtain the final output
        output = torch.matmul(attn_probs, V)
        return output

    def split_heads(self, x):
        # Reshape the input to have num_heads for multi-head attention
        batch_size, seq_length, d_model = x.size()
        return x.view(batch_size, seq_length, self.num_heads, self.d_k).transpose(1, 2)

    def combine_heads(self, x):
        # Combine the multiple heads back to original shape
        batch_size, _, seq_length, d_k = x.size()
        return x.transpose(1, 2).contiguous().view(batch_size, seq_length, self.d_model)

    def forward(self, Q, K, V):
        # Apply linear transformations and split heads
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))

        # Perform scaled dot-product attention
        attn_output = self.scaled_dot_product_attention(Q, K, V)

        # Combine heads and apply output transformation
        output = self.W_o(self.combine_heads(attn_output))
        return output

# %%
class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super(PositionWiseFeedForward, self).__init__()
        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

# %%
import math

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super(PositionalEncoding, self).__init__()

        pe = torch.zeros(max_seq_length, d_model)
        position = torch.arange(0, max_seq_length, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * -(math.log(10000.0) / d_model))

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        return x + self.pe[:, :x.size(1)]

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super(EncoderLayer, self).__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        attn_output = self.self_attn(x, x, x)
        x = self.norm1(x + self.dropout(attn_output))
        ff_output = self.feed_forward(x)
        x = self.norm2(x + self.dropout(ff_output))
        return x

# %% [markdown]
# Your task is to develop `TransformerClassifier` in which we input the embedding with the shape `[batch_size, seq_len, embed_dim]` to some `EncoderLayer` (i.e., num_layers specifies the number of EncoderLayer) and then compute the average of all token embeddings (i.e., `[batch_size, seq_len, embed_dim]`) across the `seq_len`. Finally, on the top of this average embedding, we build up a linear layer for making predictions.

# %%
class TransformerClassifier(nn.Module):
    def __init__(self, embed_dim, num_heads, ff_dim, num_layers, dropout_rate=0.2, data_manager = None):
        super(TransformerClassifier, self).__init__()
        self.vocab_size = data_manager.vocab_size
        self.num_classes = data_manager.num_classes
        self.embed_dim = embed_dim
        self.max_seq_len = data_manager.max_seq_len
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.num_layers = num_layers
        self.dropout_rate = dropout_rate

    def build(self):
        #Insert your code here
        self.embedding = nn.Embedding(self.vocab_size, self.embed_dim)
        self.positional_encoding = PositionalEncoding(self.embed_dim, self.max_seq_len)
        self.encoder_layers = nn.ModuleList([
            EncoderLayer(self.embed_dim, self.num_heads, self.ff_dim, self.dropout_rate)
            for _ in range(self.num_layers)
        ])
        self.fc = nn.Linear(self.embed_dim, self.num_classes)


    def forward(self, x):
        #Insert your code here
        x = self.embedding(x)
        x = self.positional_encoding(x)
        for layer in self.encoder_layers:
            x = layer(x)
        x = torch.mean(x, dim=1)  # Average pooling over the sequence length
        x = self.fc(x)
        return x

# %%
transformer = TransformerClassifier(embed_dim=512, num_heads=8, ff_dim=2048, num_layers=12, dropout_rate=0.1, data_manager= dm)
transformer.build()
transformer = transformer.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(transformer.parameters(), lr=1e-4, betas=(0.9, 0.98), eps=1e-9)
trainer = BaseTrainer(model= transformer, criterion=criterion, optimizer=optimizer, train_loader=dm.train_loader, val_loader=dm.valid_loader)
trainer.fit(num_epochs=30)
# Out:
# Epoch 1/30
# 26/26 - train_loss: 2.0195 - train_accuracy: 22.4235%                 - val_loss: 0.8066 - val_accuracy: 12.6263%
# Epoch 2/30
# 26/26 - train_loss: 1.7231 - train_accuracy: 18.8007%                 - val_loss: 0.8273 - val_accuracy: 12.6263%
# Epoch 3/30
# 26/26 - train_loss: 1.6846 - train_accuracy: 21.9238%                 - val_loss: 0.8405 - val_accuracy: 26.2626%
# Epoch 4/30
# 26/26 - train_loss: 1.6877 - train_accuracy: 21.9863%                 - val_loss: 0.7703 - val_accuracy: 27.2727%
# Epoch 5/30
# 26/26 - train_loss: 1.6988 - train_accuracy: 20.8620%                 - val_loss: 0.7288 - val_accuracy: 27.2727%
# Epoch 6/30
# 26/26 - train_loss: 1.6803 - train_accuracy: 21.3616%                 - val_loss: 0.7095 - val_accuracy: 27.2727%
# Epoch 7/30
# 26/26 - train_loss: 1.6394 - train_accuracy: 26.2961%                 - val_loss: 0.7327 - val_accuracy: 37.3737%
# Epoch 8/30
# 26/26 - train_loss: 1.3546 - train_accuracy: 39.0381%                 - val_loss: 0.7154 - val_accuracy: 45.9596%
# Epoch 9/30
# 26/26 - train_loss: 1.3272 - train_accuracy: 38.1012%                 - val_loss: 0.6424 - val_accuracy: 45.9596%
# Epoch 10/30
# 26/26 - train_loss: 1.3285 - train_accuracy: 40.0999%                 - val_loss: 0.6812 - val_accuracy: 45.9596%
# Epoch 11/30
# 26/26 - train_loss: 1.3192 - train_accuracy: 40.2249%                 - val_loss: 0.6634 - val_accuracy: 45.9596%
# Epoch 12/30
# 26/26 - train_loss: 1.3510 - train_accuracy: 39.7876%                 - val_loss: 0.6724 - val_accuracy: 45.9596%
# Epoch 13/30
# 26/26 - train_loss: 1.3148 - train_accuracy: 39.2879%                 - val_loss: 0.6609 - val_accuracy: 45.9596%
# Epoch 14/30
# 26/26 - train_loss: 1.3372 - train_accuracy: 40.3498%                 - val_loss: 0.6674 - val_accuracy: 45.9596%
# Epoch 15/30
# 26/26 - train_loss: 1.2693 - train_accuracy: 39.4753%                 - val_loss: 0.6418 - val_accuracy: 45.9596%
# Epoch 16/30
# 26/26 - train_loss: 1.3000 - train_accuracy: 40.3498%                 - val_loss: 0.6322 - val_accuracy: 45.9596%
# Epoch 17/30
# 26/26 - train_loss: 1.3425 - train_accuracy: 37.6640%                 - val_loss: 0.6534 - val_accuracy: 45.9596%
# Epoch 18/30
# 26/26 - train_loss: 1.3300 - train_accuracy: 39.2255%                 - val_loss: 0.6646 - val_accuracy: 36.8687%
# Epoch 19/30
# 26/26 - train_loss: 1.3459 - train_accuracy: 40.5372%                 - val_loss: 0.7054 - val_accuracy: 45.9596%
# Epoch 20/30
# 26/26 - train_loss: 1.3215 - train_accuracy: 39.5378%                 - val_loss: 0.7002 - val_accuracy: 45.9596%
# Epoch 21/30
# 26/26 - train_loss: 1.3370 - train_accuracy: 38.5384%                 - val_loss: 0.6775 - val_accuracy: 45.9596%
# Epoch 22/30
# 26/26 - train_loss: 1.3407 - train_accuracy: 37.8513%                 - val_loss: 0.6531 - val_accuracy: 45.9596%
# Epoch 23/30
# 26/26 - train_loss: 1.3834 - train_accuracy: 37.1018%                 - val_loss: 0.6508 - val_accuracy: 45.9596%
# Epoch 24/30
# 26/26 - train_loss: 1.3347 - train_accuracy: 40.9744%                 - val_loss: 0.6409 - val_accuracy: 45.9596%
# Epoch 25/30
# 26/26 - train_loss: 1.3191 - train_accuracy: 37.7264%                 - val_loss: 0.6576 - val_accuracy: 36.8687%
# Epoch 26/30
# 26/26 - train_loss: 1.2611 - train_accuracy: 41.7864%                 - val_loss: 0.6784 - val_accuracy: 45.9596%
# Epoch 27/30
# 26/26 - train_loss: 1.2581 - train_accuracy: 39.6002%                 - val_loss: 0.6743 - val_accuracy: 45.9596%
# Epoch 28/30
# 26/26 - train_loss: 1.3157 - train_accuracy: 40.0375%                 - val_loss: 0.7012 - val_accuracy: 45.9596%
# Epoch 29/30
# 26/26 - train_loss: 1.3079 - train_accuracy: 38.3510%                 - val_loss: 0.6210 - val_accuracy: 45.9596%
# Epoch 30/30
# 26/26 - train_loss: 1.3189 - train_accuracy: 41.3492%                 - val_loss: 0.6876 - val_accuracy: 45.9596%

# %% [markdown]
# #### <font color="red">**Question 4.2**</font>
# **Prefix prompt-tuning with Transformers: You need to implement the prefix prompt-tuning with Transformers. Basically, we base on a pre-trained Transformer, add prefix prompts, and do fine-tuning for a target dataset.**
#
# <div style="text-align: right"><font color="red; font-weight:bold">[Total marks for this part: 10 marks]<span></div>

# %% [markdown]
# To implement prefix prompt-tuning with pretrained Transformers, we first need to create the Bert dataset.

# %%
from transformers import AutoModel, AutoTokenizer, AdamW
from datasets import Dataset

model_name = "bert-base-uncased"  # BERT or any similar model

# Tokenize input and prepare model inputs
tokenizer = AutoTokenizer.from_pretrained(model_name)

dataset = Dataset.from_dict({"text": dm.str_questions, "label": dm.numeral_labels})

# Tokenize the dataset
def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True, max_length= 36)

dataset = dataset.map(tokenize_function, batched=True)
dataset.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
print(dataset)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'label', 'input_ids', 'token_type_ids', 'attention_mask'],
#     num_rows: 2000
# })

# %% [markdown]
# The following function splits the BERT dataset `dataset` into three BERT datasets for training, valid, and testing.

# %%
def train_valid_test_split(dataset, train_ratio=0.8, test_ratio = 0.1):
    num_sentences = len(dataset)
    train_size = int(num_sentences*train_ratio) +1
    test_size = int(num_sentences*test_ratio) +1
    valid_size = num_sentences - (train_size + test_size)
    train_set = dataset[:train_size]
    train_set = Dataset.from_dict(train_set)
    train_set.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    test_set = dataset[-test_size:]
    test_set = Dataset.from_dict(test_set)
    test_set.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    valid_set = dataset[train_size:-test_size]
    valid_set = Dataset.from_dict(valid_set)
    valid_set.set_format(type="torch", columns=["input_ids", "attention_mask", "label"])
    train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
    test_loader = DataLoader(test_set, batch_size=64, shuffle=False)
    valid_loader = DataLoader(valid_set, batch_size=64, shuffle=False)
    return train_loader, test_loader, valid_loader

# %%
train_loader, test_loader, valid_loader = train_valid_test_split(dataset)

# %% [markdown]
# You need to implement the class `PrefixTuningForClassification` for the prefix prompt fine-tuning. We first load a pre-trained BERT model specified by `model_name`. The parameter `prefix_length` specifies the length of the prefix prompts we add to the pre-trained BERT model. Specifically, given the input batch `[batch_size, seq_len]`, we input to the embedding layer of the pre-trained BERT model to obtain `[batch_size, seq_len, embed_size]`. We create the prefix prompts $P$ of the size `[prefix_length, embed_size]` and concatenate to the embeddings from the pre-trained BERT to obtain `[batch_size, seq_len + prefix_length, embed_size]`. This concatenation tensor will then be fed to the encoder layers of the pre-trained BERT layer to obtain the last `[batch_size, seq_len + prefix_length, embed_size]`.

# %% [markdown]
# We then take mean across the seq_len to obtain `[batch_size, embed_size]` on which we can build up a linear layer for making predictions. Please note that **the parameters to tune include the prefix prompts $P$** and **the output linear layer**, and you should freeze the parameters of the BERT pre-trained model. Moreover, your code should cover the edge case when `prefix_length=None`. In this case, we do not insert any prefix prompts and we only do fine-tuning for the output linear layer on top.

# %%
class PrefixTuningForClassification(nn.Module):
    def __init__(self, model_name, prefix_length=None, data_manager = None):
        super(PrefixTuningForClassification, self).__init__()

        # Load the pretrained transformer model (BERT-like model)
        self.model = AutoModel.from_pretrained(model_name).to(device)
        self.hidden_size =  self.model.config.hidden_size
        self.prefix_length = prefix_length
        self.num_classes = data_manager.num_classes
        # Insert your code here

        if prefix_length is not None:
            self.prefix_embeddings = nn.Parameter(torch.randn(prefix_length, self.hidden_size))
        else:
            self.prefix_embeddings = None

        self.classifier = nn.Linear(self.hidden_size, self.num_classes)

        # Freeze the BERT model parameters
        for param in self.model.parameters():
            param.requires_grad = False

    def forward(self, input_ids, attention_mask):
        # Insert your code here
        outputs = self.model(input_ids=input_ids, attention_mask=attention_mask)
        hidden_states = outputs.last_hidden_state

        if self.prefix_length is not None:
            prefix_embeddings = self.prefix_embeddings.unsqueeze(0).expand(input_ids.size(0), -1, -1)
            hidden_states = torch.cat([prefix_embeddings, hidden_states], dim=1)
            attention_mask = torch.cat([torch.ones(input_ids.size(0), self.prefix_length).to(device), attention_mask], dim=1)

        hidden_states = torch.mean(hidden_states, dim=1)  # Average pooling over the sequence length
        logits = self.classifier(hidden_states)
        return logits

# %% [markdown]
# You can use the following `FineTunedBaseTrainer` to train the prompt fine-tuning models.

# %%
class FineTunedBaseTrainer:
    def __init__(self, model, criterion, optimizer, train_loader, val_loader):
        self.model = model
        self.criterion = criterion  #the loss function
        self.optimizer = optimizer  #the optimizer
        self.train_loader = train_loader  #the train loader
        self.val_loader = val_loader  #the valid loader

    #the function to train the model in many epochs
    def fit(self, num_epochs):
        self.num_batches = len(self.train_loader)

        for epoch in range(num_epochs):
            print(f'Epoch {epoch + 1}/{num_epochs}')
            train_loss, train_accuracy = self.train_one_epoch()
            val_loss, val_accuracy = self.validate_one_epoch()
            print(
                f'{self.num_batches}/{self.num_batches} - train_loss: {train_loss:.4f} - train_accuracy: {train_accuracy*100:.4f}% \
                - val_loss: {val_loss:.4f} - val_accuracy: {val_accuracy*100:.4f}%')

    #train in one epoch, return the train_acc, train_loss
    def train_one_epoch(self):
        self.model.train()
        running_loss, correct, total = 0.0, 0, 0
        for batch in self.train_loader:
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)
            self.optimizer.zero_grad()
            outputs = self.model(input_ids= input_ids, attention_mask= attention_mask)
            loss = self.criterion(outputs, labels)
            loss.backward()
            self.optimizer.step()

            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        train_accuracy = correct / total
        train_loss = running_loss / self.num_batches
        return train_loss, train_accuracy

    #evaluate on a loader and return the loss and accuracy
    def evaluate(self, loader):
        self.model.eval()
        loss, correct, total = 0.0, 0, 0
        with torch.no_grad():
            for batch in loader:
                input_ids = batch["input_ids"].to(device)
                labels = batch["label"].to(device)
                attention_mask = batch["attention_mask"].to(device)
                outputs = self.model(input_ids= input_ids, attention_mask= attention_mask)
                loss = self.criterion(outputs, labels)
                loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        accuracy = correct / total
        loss = loss / len(self.val_loader)
        return loss, accuracy

    #return the val_acc, val_loss, be called at the end of each epoch
    def validate_one_epoch(self):
      val_loss, val_accuracy = self.evaluate(self.val_loader)
      return val_loss, val_accuracy

# %% [markdown]
# We declare and train the prefix-prompt tuning model. In addition, you need to be patient with this model because it might converge slowly with many epochs.

# %%
prefix_tuning_model = PrefixTuningForClassification(model_name = "bert-base-uncased", prefix_length = 5, data_manager = dm).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
if prefix_tuning_model.prefix_length is not None:
  optimizer = torch.optim.Adam(list(prefix_tuning_model.classifier.parameters()) + [prefix_tuning_model.prefix_embeddings], lr=5e-5)
else:
  optimizer = torch.optim.Adam(prefix_tuning_model.classifier.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss()
trainer = FineTunedBaseTrainer(model= prefix_tuning_model, criterion=criterion, optimizer=optimizer, train_loader=train_loader, val_loader=valid_loader)
trainer.fit(num_epochs=100)
# Out:
# Epoch 1/100
# 26/26 - train_loss: 1.7448 - train_accuracy: 26.4210%                 - val_loss: 0.8864 - val_accuracy: 30.3030%
# Epoch 2/100
# 26/26 - train_loss: 1.7180 - train_accuracy: 32.4172%                 - val_loss: 0.8622 - val_accuracy: 36.8687%
# Epoch 3/100
# 26/26 - train_loss: 1.6704 - train_accuracy: 38.6009%                 - val_loss: 0.8422 - val_accuracy: 43.4343%
# Epoch 4/100
# 26/26 - train_loss: 1.6426 - train_accuracy: 41.7864%                 - val_loss: 0.8244 - val_accuracy: 46.4646%
# Epoch 5/100
# 26/26 - train_loss: 1.6200 - train_accuracy: 45.0968%                 - val_loss: 0.8050 - val_accuracy: 47.9798%
# Epoch 6/100
# 26/26 - train_loss: 1.5969 - train_accuracy: 45.7214%                 - val_loss: 0.7909 - val_accuracy: 48.9899%
# Epoch 7/100
# 26/26 - train_loss: 1.5810 - train_accuracy: 47.3454%                 - val_loss: 0.7773 - val_accuracy: 53.0303%
# Epoch 8/100
# 26/26 - train_loss: 1.5468 - train_accuracy: 50.6558%                 - val_loss: 0.7630 - val_accuracy: 55.5556%
# Epoch 9/100
# 26/26 - train_loss: 1.5331 - train_accuracy: 50.9681%                 - val_loss: 0.7521 - val_accuracy: 56.0606%
# Epoch 10/100
# 26/26 - train_loss: 1.4999 - train_accuracy: 53.3417%                 - val_loss: 0.7368 - val_accuracy: 59.5960%
# Epoch 11/100
# 26/26 - train_loss: 1.5047 - train_accuracy: 54.5909%                 - val_loss: 0.7288 - val_accuracy: 60.6061%
# Epoch 12/100
# 26/26 - train_loss: 1.4745 - train_accuracy: 59.0256%                 - val_loss: 0.7171 - val_accuracy: 62.6263%
# Epoch 13/100
# 26/26 - train_loss: 1.4513 - train_accuracy: 59.0881%                 - val_loss: 0.7031 - val_accuracy: 62.1212%
# Epoch 14/100
# 26/26 - train_loss: 1.4440 - train_accuracy: 62.0862%                 - val_loss: 0.6967 - val_accuracy: 64.1414%
# Epoch 15/100
# 26/26 - train_loss: 1.4275 - train_accuracy: 60.7745%                 - val_loss: 0.6882 - val_accuracy: 64.6465%
# Epoch 16/100
# 26/26 - train_loss: 1.4222 - train_accuracy: 61.8364%                 - val_loss: 0.6795 - val_accuracy: 64.6465%
# Epoch 17/100
# 26/26 - train_loss: 1.3859 - train_accuracy: 64.3348%                 - val_loss: 0.6680 - val_accuracy: 69.6970%
# Epoch 18/100
# 26/26 - train_loss: 1.3871 - train_accuracy: 65.7714%                 - val_loss: 0.6553 - val_accuracy: 70.7071%
# Epoch 19/100
# 26/26 - train_loss: 1.3807 - train_accuracy: 66.9582%                 - val_loss: 0.6477 - val_accuracy: 70.2020%
# Epoch 20/100
# 26/26 - train_loss: 1.3546 - train_accuracy: 67.7077%                 - val_loss: 0.6408 - val_accuracy: 71.2121%
# Epoch 21/100
# 26/26 - train_loss: 1.3531 - train_accuracy: 68.7695%                 - val_loss: 0.6336 - val_accuracy: 71.2121%
# Epoch 22/100
# 26/26 - train_loss: 1.3446 - train_accuracy: 69.4566%                 - val_loss: 0.6294 - val_accuracy: 73.2323%
# Epoch 23/100
# 26/26 - train_loss: 1.3347 - train_accuracy: 71.8301%                 - val_loss: 0.6242 - val_accuracy: 75.7576%
# Epoch 24/100
# 26/26 - train_loss: 1.3127 - train_accuracy: 73.1418%                 - val_loss: 0.6149 - val_accuracy: 79.7980%
# Epoch 25/100
# 26/26 - train_loss: 1.2765 - train_accuracy: 73.9538%                 - val_loss: 0.6059 - val_accuracy: 80.8081%
# Epoch 26/100
# 26/26 - train_loss: 1.2767 - train_accuracy: 75.5778%                 - val_loss: 0.5950 - val_accuracy: 80.8081%
# Epoch 27/100
# 26/26 - train_loss: 1.2794 - train_accuracy: 74.8282%                 - val_loss: 0.5879 - val_accuracy: 81.3131%
# Epoch 28/100
# 26/26 - train_loss: 1.2598 - train_accuracy: 76.3273%                 - val_loss: 0.5806 - val_accuracy: 82.3232%
# Epoch 29/100
# 26/26 - train_loss: 1.2563 - train_accuracy: 76.5147%                 - val_loss: 0.5704 - val_accuracy: 82.3232%
# Epoch 30/100
# 26/26 - train_loss: 1.2491 - train_accuracy: 75.9525%                 - val_loss: 0.5646 - val_accuracy: 81.8182%
# Epoch 31/100
# 26/26 - train_loss: 1.2107 - train_accuracy: 79.1380%                 - val_loss: 0.5591 - val_accuracy: 83.3333%
# Epoch 32/100
# 26/26 - train_loss: 1.2163 - train_accuracy: 79.3879%                 - val_loss: 0.5562 - val_accuracy: 83.3333%
# Epoch 33/100
# 26/26 - train_loss: 1.2164 - train_accuracy: 78.2011%                 - val_loss: 0.5497 - val_accuracy: 83.8384%
# Epoch 34/100
# 26/26 - train_loss: 1.2162 - train_accuracy: 78.6384%                 - val_loss: 0.5424 - val_accuracy: 84.3434%
# Epoch 35/100
# 26/26 - train_loss: 1.1875 - train_accuracy: 79.8876%                 - val_loss: 0.5349 - val_accuracy: 84.8485%
# Epoch 36/100
# 26/26 - train_loss: 1.1749 - train_accuracy: 79.5128%                 - val_loss: 0.5251 - val_accuracy: 84.8485%
# Epoch 37/100
# 26/26 - train_loss: 1.1738 - train_accuracy: 79.9500%                 - val_loss: 0.5197 - val_accuracy: 84.8485%
# Epoch 38/100
# 26/26 - train_loss: 1.1645 - train_accuracy: 80.3248%                 - val_loss: 0.5116 - val_accuracy: 84.3434%
# Epoch 39/100
# 26/26 - train_loss: 1.1502 - train_accuracy: 81.1993%                 - val_loss: 0.5068 - val_accuracy: 84.8485%
# Epoch 40/100
# 26/26 - train_loss: 1.1484 - train_accuracy: 81.0743%                 - val_loss: 0.5029 - val_accuracy: 84.8485%
# Epoch 41/100
# 26/26 - train_loss: 1.1378 - train_accuracy: 82.5109%                 - val_loss: 0.5011 - val_accuracy: 85.8586%
# Epoch 42/100
# 26/26 - train_loss: 1.2054 - train_accuracy: 81.0743%                 - val_loss: 0.4959 - val_accuracy: 85.8586%
# Epoch 43/100
# 26/26 - train_loss: 1.1326 - train_accuracy: 82.6359%                 - val_loss: 0.4902 - val_accuracy: 85.3535%
# Epoch 44/100
# 26/26 - train_loss: 1.1080 - train_accuracy: 82.4485%                 - val_loss: 0.4850 - val_accuracy: 86.8687%
# Epoch 45/100
# 26/26 - train_loss: 1.1035 - train_accuracy: 83.0106%                 - val_loss: 0.4804 - val_accuracy: 86.3636%
# Epoch 46/100
# 26/26 - train_loss: 1.0811 - train_accuracy: 82.3860%                 - val_loss: 0.4760 - val_accuracy: 85.8586%
# Epoch 47/100
# 26/26 - train_loss: 1.0819 - train_accuracy: 82.8232%                 - val_loss: 0.4709 - val_accuracy: 86.3636%
# Epoch 48/100
# 26/26 - train_loss: 1.0600 - train_accuracy: 82.3235%                 - val_loss: 0.4666 - val_accuracy: 86.3636%
# Epoch 49/100
# 26/26 - train_loss: 1.0523 - train_accuracy: 82.2611%                 - val_loss: 0.4588 - val_accuracy: 85.8586%
# Epoch 50/100
# 26/26 - train_loss: 1.0535 - train_accuracy: 82.4485%                 - val_loss: 0.4518 - val_accuracy: 86.3636%
# Epoch 51/100
# 26/26 - train_loss: 1.0526 - train_accuracy: 83.1355%                 - val_loss: 0.4489 - val_accuracy: 85.8586%
# Epoch 52/100
# 26/26 - train_loss: 1.0461 - train_accuracy: 81.6989%                 - val_loss: 0.4467 - val_accuracy: 86.3636%
# Epoch 53/100
# 26/26 - train_loss: 1.0408 - train_accuracy: 81.4491%                 - val_loss: 0.4423 - val_accuracy: 86.8687%
# Epoch 54/100
# 26/26 - train_loss: 1.0032 - train_accuracy: 82.5734%                 - val_loss: 0.4381 - val_accuracy: 86.8687%
# Epoch 55/100
# 26/26 - train_loss: 0.9950 - train_accuracy: 83.0731%                 - val_loss: 0.4319 - val_accuracy: 86.3636%
# Epoch 56/100
# 26/26 - train_loss: 1.0410 - train_accuracy: 83.5728%                 - val_loss: 0.4256 - val_accuracy: 86.8687%
# Epoch 57/100
# 26/26 - train_loss: 1.0240 - train_accuracy: 83.5728%                 - val_loss: 0.4260 - val_accuracy: 87.3737%
# Epoch 58/100
# 26/26 - train_loss: 0.9990 - train_accuracy: 83.5103%                 - val_loss: 0.4207 - val_accuracy: 87.3737%
# Epoch 59/100
# 26/26 - train_loss: 0.9811 - train_accuracy: 84.7595%                 - val_loss: 0.4141 - val_accuracy: 87.3737%
# Epoch 60/100
# 26/26 - train_loss: 0.9896 - train_accuracy: 84.3223%                 - val_loss: 0.4095 - val_accuracy: 87.8788%
# Epoch 61/100
# 26/26 - train_loss: 0.9661 - train_accuracy: 85.0094%                 - val_loss: 0.4062 - val_accuracy: 86.8687%
# Epoch 62/100
# 26/26 - train_loss: 0.9631 - train_accuracy: 84.1974%                 - val_loss: 0.4031 - val_accuracy: 87.3737%
# Epoch 63/100
# 26/26 - train_loss: 0.9396 - train_accuracy: 84.3848%                 - val_loss: 0.4001 - val_accuracy: 86.8687%
# Epoch 64/100
# 26/26 - train_loss: 0.9402 - train_accuracy: 85.3217%                 - val_loss: 0.3980 - val_accuracy: 87.8788%
# Epoch 65/100
# 26/26 - train_loss: 0.9580 - train_accuracy: 84.8220%                 - val_loss: 0.3965 - val_accuracy: 88.3838%
# Epoch 66/100
# 26/26 - train_loss: 0.9436 - train_accuracy: 84.4472%                 - val_loss: 0.3964 - val_accuracy: 88.3838%
# Epoch 67/100
# 26/26 - train_loss: 0.9527 - train_accuracy: 85.6340%                 - val_loss: 0.3938 - val_accuracy: 88.8889%
# Epoch 68/100
# 26/26 - train_loss: 0.9049 - train_accuracy: 86.5084%                 - val_loss: 0.3873 - val_accuracy: 88.8889%
# Epoch 69/100
# 26/26 - train_loss: 0.9137 - train_accuracy: 86.3835%                 - val_loss: 0.3849 - val_accuracy: 88.8889%
# Epoch 70/100
# 26/26 - train_loss: 0.9246 - train_accuracy: 85.8214%                 - val_loss: 0.3798 - val_accuracy: 88.8889%
# Epoch 71/100
# 26/26 - train_loss: 0.9087 - train_accuracy: 85.5715%                 - val_loss: 0.3760 - val_accuracy: 88.8889%
# Epoch 72/100
# 26/26 - train_loss: 0.9169 - train_accuracy: 85.6964%                 - val_loss: 0.3739 - val_accuracy: 89.3939%
# Epoch 73/100
# 26/26 - train_loss: 0.9120 - train_accuracy: 86.3835%                 - val_loss: 0.3704 - val_accuracy: 88.8889%
# Epoch 74/100
# 26/26 - train_loss: 0.8883 - train_accuracy: 85.9463%                 - val_loss: 0.3674 - val_accuracy: 87.8788%
# Epoch 75/100
# 26/26 - train_loss: 0.9147 - train_accuracy: 84.9469%                 - val_loss: 0.3638 - val_accuracy: 88.3838%
# Epoch 76/100
# 26/26 - train_loss: 0.8553 - train_accuracy: 84.8220%                 - val_loss: 0.3588 - val_accuracy: 87.8788%
# Epoch 77/100
# 26/26 - train_loss: 0.8592 - train_accuracy: 86.0712%                 - val_loss: 0.3543 - val_accuracy: 88.8889%
# Epoch 78/100
# 26/26 - train_loss: 0.8671 - train_accuracy: 85.8214%                 - val_loss: 0.3524 - val_accuracy: 88.8889%
# Epoch 79/100
# 26/26 - train_loss: 0.8627 - train_accuracy: 85.9463%                 - val_loss: 0.3487 - val_accuracy: 88.8889%
# Epoch 80/100
# 26/26 - train_loss: 0.8484 - train_accuracy: 85.8214%                 - val_loss: 0.3440 - val_accuracy: 88.8889%
# Epoch 81/100
# 26/26 - train_loss: 0.8394 - train_accuracy: 85.8214%                 - val_loss: 0.3396 - val_accuracy: 88.8889%
# Epoch 82/100
# 26/26 - train_loss: 0.8534 - train_accuracy: 85.7589%                 - val_loss: 0.3391 - val_accuracy: 88.3838%
# Epoch 83/100
# 26/26 - train_loss: 0.8575 - train_accuracy: 86.5084%                 - val_loss: 0.3388 - val_accuracy: 89.3939%
# Epoch 84/100
# 26/26 - train_loss: 0.8232 - train_accuracy: 86.1961%                 - val_loss: 0.3363 - val_accuracy: 89.3939%
# Epoch 85/100
# 26/26 - train_loss: 0.8302 - train_accuracy: 86.9457%                 - val_loss: 0.3343 - val_accuracy: 89.3939%
# Epoch 86/100
# 26/26 - train_loss: 0.8358 - train_accuracy: 87.3204%                 - val_loss: 0.3319 - val_accuracy: 89.8990%
# Epoch 87/100
# 26/26 - train_loss: 0.8371 - train_accuracy: 86.3835%                 - val_loss: 0.3287 - val_accuracy: 89.8990%
# Epoch 88/100
# 26/26 - train_loss: 0.8355 - train_accuracy: 86.8832%                 - val_loss: 0.3290 - val_accuracy: 89.8990%
# Epoch 89/100
# 26/26 - train_loss: 0.8142 - train_accuracy: 86.3835%                 - val_loss: 0.3281 - val_accuracy: 89.8990%
# Epoch 90/100
# 26/26 - train_loss: 0.8160 - train_accuracy: 87.3829%                 - val_loss: 0.3225 - val_accuracy: 89.3939%
# Epoch 91/100
# 26/26 - train_loss: 0.7959 - train_accuracy: 87.0706%                 - val_loss: 0.3198 - val_accuracy: 89.8990%
# Epoch 92/100
# 26/26 - train_loss: 0.8105 - train_accuracy: 87.2580%                 - val_loss: 0.3169 - val_accuracy: 89.8990%
# Epoch 93/100
# 26/26 - train_loss: 0.7984 - train_accuracy: 87.3204%                 - val_loss: 0.3158 - val_accuracy: 89.3939%
# Epoch 94/100
# 26/26 - train_loss: 0.7808 - train_accuracy: 86.8832%                 - val_loss: 0.3130 - val_accuracy: 90.4040%
# Epoch 95/100
# 26/26 - train_loss: 0.7852 - train_accuracy: 87.5078%                 - val_loss: 0.3108 - val_accuracy: 90.9091%
# Epoch 96/100
# 26/26 - train_loss: 0.7586 - train_accuracy: 87.1330%                 - val_loss: 0.3059 - val_accuracy: 90.9091%
# Epoch 97/100
# 26/26 - train_loss: 0.7757 - train_accuracy: 87.8201%                 - val_loss: 0.3039 - val_accuracy: 90.9091%
# Epoch 98/100
# 26/26 - train_loss: 0.7528 - train_accuracy: 88.0075%                 - val_loss: 0.3005 - val_accuracy: 91.9192%
# Epoch 99/100
# 26/26 - train_loss: 0.7502 - train_accuracy: 87.7577%                 - val_loss: 0.2967 - val_accuracy: 91.9192%
# Epoch 100/100
# 26/26 - train_loss: 0.7643 - train_accuracy: 88.3823%                 - val_loss: 0.2956 - val_accuracy: 91.9192%

# %% [markdown]
# #### <font color="red">**Question 4.3**</font>
# **For any models defined in the previous questions (of all parts), you are free to fine-tune hyperparameters, e.g., `optimizer`, `learning_rate`, `state_sizes`, such that you get a best model, i.e., the one with the highest accuracy on the test set. You will need to report (i) what is your best model,  (ii) its accuracy on the test set, and (iii) the values of its hyperparameters. Note that you must report your best model's accuracy with rounding to 4 decimal places, i.e., 0.xxxx. You will also need to upload your best model (or provide us with the link to download your best model). The assessment will be based on your best model's accuracy, with up to 9 marks available, specifically:**
# * The best accuracy $\ge$ 0.97: 10 marks
# * 0.97 $>$ The best accuracy $\ge$ 0.92: 7 marks
# * 0.92 $>$ The best accuracy $\ge$ 0.85: 4 marks
# * The best accuracy $<$ 0.85: 0 mark
#
# **For this question, you can put below the code to train the best model. In this case, you need to show your code and the evidence of running regarding the best model. Moreover, if you save the best model, you need to provide the link to download the best model, the code to load the best model, and then evaluate on the test set.**
# <div style="text-align: right"><font color="red">[10 marks]</font></div>

# %%
# Example of fine-tuning hyperparameters
best_accuracy = 0.0
best_model = None
best_hyperparameters = {}

# Hyperparameter grid
learning_rates = [1e-4, 5e-5, 1e-5]
dropout_rates = [0.1, 0.2, 0.3]
num_layers = [6, 12]

for lr in learning_rates:
    for dropout in dropout_rates:
        for layers in num_layers:
            transformer = TransformerClassifier(embed_dim=512, num_heads=8, ff_dim=2048, num_layers=layers, dropout_rate=dropout, data_manager=dm)
            transformer.build()
            transformer = transformer.to(device)
            criterion = nn.CrossEntropyLoss()
            optimizer = torch.optim.Adam(transformer.parameters(), lr=lr, betas=(0.9, 0.98), eps=1e-9)
            trainer = BaseTrainer(model=transformer, criterion=criterion, optimizer=optimizer, train_loader=dm.train_loader, val_loader=dm.valid_loader)
            trainer.fit(num_epochs=30)

            # Evaluate on the test set
            test_loss, test_accuracy = trainer.evaluate(dm.test_loader)
            print(f"Learning Rate: {lr}, Dropout: {dropout}, Num Layers: {layers}, Test Accuracy: {test_accuracy:.4f}")

            if test_accuracy > best_accuracy:
                best_accuracy = test_accuracy
                best_model = transformer
                best_hyperparameters = {'lr': lr, 'dropout': dropout, 'num_layers': layers}

# Save the best model
torch.save(best_model.state_dict(), 'best_model.pth')

# Report the best model
print(f"Best Model Accuracy: {best_accuracy:.4f}")
print(f"Best Hyperparameters: {best_hyperparameters}")

# Load the best model and evaluate on the test set
best_model = TransformerClassifier(embed_dim=512, num_heads=8, ff_dim=2048, num_layers=best_hyperparameters['num_layers'], dropout_rate=best_hyperparameters['dropout'], data_manager=dm)
best_model.build()
best_model.load_state_dict(torch.load('best_model.pth'))
best_model = best_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(best_model.parameters(), lr=best_hyperparameters['lr'], betas=(0.9, 0.98), eps=1e-9)
trainer = BaseTrainer(model=best_model, criterion=criterion, optimizer=optimizer, train_loader=dm.train_loader, val_loader=dm.valid_loader)
test_loss, test_accuracy = trainer.evaluate(dm.test_loader)
print(f"Best Model Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/30
# 26/26 - train_loss: 1.6990 - train_accuracy: 27.3579%                 - val_loss: 0.8206 - val_accuracy: 35.8586%
# Epoch 2/30
# 26/26 - train_loss: 0.8043 - train_accuracy: 67.5203%                 - val_loss: 0.0589 - val_accuracy: 90.9091%
# Epoch 3/30
# 26/26 - train_loss: 0.1698 - train_accuracy: 94.0037%                 - val_loss: 0.0202 - val_accuracy: 93.9394%
# Epoch 4/30
# 26/26 - train_loss: 0.0757 - train_accuracy: 97.0019%                 - val_loss: 0.0053 - val_accuracy: 94.9495%
# Epoch 5/30
# 26/26 - train_loss: 0.0828 - train_accuracy: 96.8770%                 - val_loss: 0.0021 - val_accuracy: 94.9495%
# Epoch 6/30
# 26/26 - train_loss: 0.0589 - train_accuracy: 97.5016%                 - val_loss: 0.0007 - val_accuracy: 95.4545%
# Epoch 7/30
# 26/26 - train_loss: 0.0322 - train_accuracy: 98.6883%                 - val_loss: 0.0005 - val_accuracy: 95.4545%
# Epoch 8/30
# 26/26 - train_loss: 0.0266 - train_accuracy: 99.1880%                 - val_loss: 0.0002 - val_accuracy: 95.9596%
# Epoch 9/30
# 26/26 - train_loss: 0.0182 - train_accuracy: 99.1880%                 - val_loss: 0.0001 - val_accuracy: 96.4646%
# Epoch 10/30
# 26/26 - train_loss: 0.0162 - train_accuracy: 99.3754%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 11/30
# 26/26 - train_loss: 0.0063 - train_accuracy: 99.7502%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 12/30
# 26/26 - train_loss: 0.0007 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.9596%
# Epoch 13/30
# 26/26 - train_loss: 0.0050 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 14/30
# 26/26 - train_loss: 0.0162 - train_accuracy: 99.5628%                 - val_loss: 0.0133 - val_accuracy: 93.4343%
# Epoch 15/30
# 26/26 - train_loss: 0.0143 - train_accuracy: 99.5003%                 - val_loss: 0.0001 - val_accuracy: 95.9596%
# Epoch 16/30
# 26/26 - train_loss: 0.0021 - train_accuracy: 99.9375%                 - val_loss: 0.0001 - val_accuracy: 94.9495%
# Epoch 17/30
# 26/26 - train_loss: 0.0026 - train_accuracy: 99.9375%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 18/30
# 26/26 - train_loss: 0.0004 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.9596%
# Epoch 19/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.9596%
# Epoch 20/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.9596%
# Epoch 21/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.9596%
# Epoch 22/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.9596%
# Epoch 23/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 24/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 25/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 26/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 27/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 28/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 29/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 30/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Learning Rate: 0.0001, Dropout: 0.1, Num Layers: 6, Test Accuracy: 0.9602
# Epoch 1/30
# 26/26 - train_loss: 1.8809 - train_accuracy: 19.1131%                 - val_loss: 0.8445 - val_accuracy: 14.6465%
# Epoch 2/30
# 26/26 - train_loss: 1.7149 - train_accuracy: 21.1118%                 - val_loss: 0.7471 - val_accuracy: 18.1818%
# Epoch 3/30
# 26/26 - train_loss: 1.6758 - train_accuracy: 21.9238%                 - val_loss: 0.7615 - val_accuracy: 18.1818%
# Epoch 4/30
# 26/26 - train_loss: 1.5218 - train_accuracy: 34.4785%                 - val_loss: 0.7402 - val_accuracy: 36.8687%
# Epoch 5/30
# 26/26 - train_loss: 0.9760 - train_accuracy: 59.0881%                 - val_loss: 0.4465 - val_accuracy: 61.1111%
# Epoch 6/30
# 26/26 - train_loss: 0.6411 - train_accuracy: 73.3292%                 - val_loss: 0.2969 - val_accuracy: 82.3232%
# Epoch 7/30
# 26/26 - train_loss: 0.3189 - train_accuracy: 88.7570%                 - val_loss: 0.0200 - val_accuracy: 91.4141%
# Epoch 8/30
# 26/26 - train_loss: 0.1983 - train_accuracy: 93.2542%                 - val_loss: 0.0205 - val_accuracy: 92.9293%
# Epoch 9/30
# 26/26 - train_loss: 0.1368 - train_accuracy: 95.1905%                 - val_loss: 0.0229 - val_accuracy: 94.9495%
# Epoch 10/30
# 26/26 - train_loss: 0.1314 - train_accuracy: 96.2523%                 - val_loss: 0.0819 - val_accuracy: 92.9293%
# Epoch 11/30
# 26/26 - train_loss: 0.0944 - train_accuracy: 97.3142%                 - val_loss: 0.0276 - val_accuracy: 94.4444%
# Epoch 12/30
# 26/26 - train_loss: 0.0777 - train_accuracy: 97.4391%                 - val_loss: 0.0063 - val_accuracy: 94.4444%
# Epoch 13/30
# 26/26 - train_loss: 0.0476 - train_accuracy: 98.6883%                 - val_loss: 0.0014 - val_accuracy: 94.9495%
# Epoch 14/30
# 26/26 - train_loss: 0.0499 - train_accuracy: 98.4385%                 - val_loss: 0.0007 - val_accuracy: 95.9596%
# Epoch 15/30
# 26/26 - train_loss: 0.0244 - train_accuracy: 99.3129%                 - val_loss: 0.0017 - val_accuracy: 94.4444%
# Epoch 16/30
# 26/26 - train_loss: 0.0354 - train_accuracy: 98.4385%                 - val_loss: 0.0043 - val_accuracy: 93.9394%
# Epoch 17/30
# 26/26 - train_loss: 0.0532 - train_accuracy: 98.1886%                 - val_loss: 0.0018 - val_accuracy: 84.8485%
# Epoch 18/30
# 26/26 - train_loss: 0.1493 - train_accuracy: 94.3785%                 - val_loss: 0.0025 - val_accuracy: 95.9596%
# Epoch 19/30
# 26/26 - train_loss: 0.0099 - train_accuracy: 99.8126%                 - val_loss: 0.0009 - val_accuracy: 94.9495%
# Epoch 20/30
# 26/26 - train_loss: 0.0131 - train_accuracy: 99.7502%                 - val_loss: 0.0001 - val_accuracy: 93.9394%
# Epoch 21/30
# 26/26 - train_loss: 0.0258 - train_accuracy: 99.3129%                 - val_loss: 0.0009 - val_accuracy: 95.9596%
# Epoch 22/30
# 26/26 - train_loss: 0.0157 - train_accuracy: 99.6877%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 23/30
# 26/26 - train_loss: 0.0194 - train_accuracy: 99.1880%                 - val_loss: 0.0006 - val_accuracy: 95.4545%
# Epoch 24/30
# 26/26 - train_loss: 0.0198 - train_accuracy: 99.5003%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 25/30
# 26/26 - train_loss: 0.0211 - train_accuracy: 99.6252%                 - val_loss: 0.0002 - val_accuracy: 95.4545%
# Epoch 26/30
# 26/26 - train_loss: 0.0249 - train_accuracy: 99.6252%                 - val_loss: 0.0006 - val_accuracy: 90.9091%
# Epoch 27/30
# 26/26 - train_loss: 0.1326 - train_accuracy: 97.4391%                 - val_loss: 0.0188 - val_accuracy: 95.4545%
# Epoch 28/30
# 26/26 - train_loss: 0.0044 - train_accuracy: 99.9375%                 - val_loss: 0.0002 - val_accuracy: 95.4545%
# Epoch 29/30
# 26/26 - train_loss: 0.0004 - train_accuracy: 100.0000%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 30/30
# 26/26 - train_loss: 0.0002 - train_accuracy: 100.0000%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Learning Rate: 0.0001, Dropout: 0.1, Num Layers: 12, Test Accuracy: 0.9652
# Epoch 1/30
# 26/26 - train_loss: 1.7128 - train_accuracy: 27.8576%                 - val_loss: 0.5358 - val_accuracy: 46.4646%
# Epoch 2/30
# 26/26 - train_loss: 0.8009 - train_accuracy: 70.2061%                 - val_loss: 0.0659 - val_accuracy: 90.9091%
# Epoch 3/30
# 26/26 - train_loss: 0.2602 - train_accuracy: 92.5047%                 - val_loss: 0.0092 - val_accuracy: 92.9293%
# Epoch 4/30
# 26/26 - train_loss: 0.2618 - train_accuracy: 92.6921%                 - val_loss: 0.0040 - val_accuracy: 93.4343%
# Epoch 5/30
# 26/26 - train_loss: 0.0874 - train_accuracy: 96.5022%                 - val_loss: 0.0040 - val_accuracy: 95.9596%
# Epoch 6/30
# 26/26 - train_loss: 0.0613 - train_accuracy: 97.3142%                 - val_loss: 0.0014 - val_accuracy: 95.4545%
# Epoch 7/30
# 26/26 - train_loss: 0.0347 - train_accuracy: 98.6883%                 - val_loss: 0.0007 - val_accuracy: 94.9495%
# Epoch 8/30
# 26/26 - train_loss: 0.0407 - train_accuracy: 98.6883%                 - val_loss: 0.0003 - val_accuracy: 94.9495%
# Epoch 9/30
# 26/26 - train_loss: 0.0200 - train_accuracy: 99.3754%                 - val_loss: 0.0007 - val_accuracy: 95.4545%
# Epoch 10/30
# 26/26 - train_loss: 0.0053 - train_accuracy: 99.8751%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 11/30
# 26/26 - train_loss: 0.0045 - train_accuracy: 99.8751%                 - val_loss: 0.0002 - val_accuracy: 95.4545%
# Epoch 12/30
# 26/26 - train_loss: 0.0158 - train_accuracy: 99.3754%                 - val_loss: 0.0002 - val_accuracy: 96.4646%
# Epoch 13/30
# 26/26 - train_loss: 0.0144 - train_accuracy: 99.4379%                 - val_loss: 0.0002 - val_accuracy: 95.4545%
# Epoch 14/30
# 26/26 - train_loss: 0.0100 - train_accuracy: 99.7502%                 - val_loss: 0.0001 - val_accuracy: 96.4646%
# Epoch 15/30
# 26/26 - train_loss: 0.0019 - train_accuracy: 99.9375%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 16/30
# 26/26 - train_loss: 0.0055 - train_accuracy: 99.8126%                 - val_loss: 0.0001 - val_accuracy: 96.4646%
# Epoch 17/30
# 26/26 - train_loss: 0.0010 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.9596%
# Epoch 18/30
# 26/26 - train_loss: 0.0020 - train_accuracy: 100.0000%                 - val_loss: 0.0001 - val_accuracy: 97.4747%
# Epoch 19/30
# 26/26 - train_loss: 0.0002 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 20/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 21/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 22/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 23/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 24/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 25/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 26/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 27/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 28/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 29/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 30/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Learning Rate: 0.0001, Dropout: 0.2, Num Layers: 6, Test Accuracy: 0.9801
# Epoch 1/30
# 26/26 - train_loss: 1.9326 - train_accuracy: 18.1137%                 - val_loss: 0.7092 - val_accuracy: 14.6465%
# Epoch 2/30
# 26/26 - train_loss: 1.7090 - train_accuracy: 21.4241%                 - val_loss: 0.8536 - val_accuracy: 12.6263%
# Epoch 3/30
# 26/26 - train_loss: 1.6917 - train_accuracy: 21.1118%                 - val_loss: 0.9208 - val_accuracy: 26.2626%
# Epoch 4/30
# 26/26 - train_loss: 1.7246 - train_accuracy: 21.6740%                 - val_loss: 0.8414 - val_accuracy: 26.2626%
# Epoch 5/30
# 26/26 - train_loss: 1.6730 - train_accuracy: 20.1124%                 - val_loss: 0.8949 - val_accuracy: 12.6263%
# Epoch 6/30
# 26/26 - train_loss: 1.6862 - train_accuracy: 21.5490%                 - val_loss: 0.7251 - val_accuracy: 27.2727%
# Epoch 7/30
# 26/26 - train_loss: 1.3149 - train_accuracy: 40.3498%                 - val_loss: 0.7260 - val_accuracy: 42.9293%
# Epoch 8/30
# 26/26 - train_loss: 1.1961 - train_accuracy: 43.0356%                 - val_loss: 0.6755 - val_accuracy: 42.9293%
# Epoch 9/30
# 26/26 - train_loss: 1.2211 - train_accuracy: 43.1605%                 - val_loss: 0.7081 - val_accuracy: 52.0202%
# Epoch 10/30
# 26/26 - train_loss: 1.1804 - train_accuracy: 40.3498%                 - val_loss: 0.6633 - val_accuracy: 52.0202%
# Epoch 11/30
# 26/26 - train_loss: 1.1639 - train_accuracy: 41.7864%                 - val_loss: 0.6621 - val_accuracy: 52.0202%
# Epoch 12/30
# 26/26 - train_loss: 1.2206 - train_accuracy: 44.0974%                 - val_loss: 0.6535 - val_accuracy: 52.0202%
# Epoch 13/30
# 26/26 - train_loss: 1.1926 - train_accuracy: 40.4122%                 - val_loss: 0.6852 - val_accuracy: 42.9293%
# Epoch 14/30
# 26/26 - train_loss: 1.2068 - train_accuracy: 44.5347%                 - val_loss: 0.7366 - val_accuracy: 37.3737%
# Epoch 15/30
# 26/26 - train_loss: 1.2213 - train_accuracy: 42.4735%                 - val_loss: 0.6349 - val_accuracy: 42.9293%
# Epoch 16/30
# 26/26 - train_loss: 1.2044 - train_accuracy: 42.5359%                 - val_loss: 0.6180 - val_accuracy: 52.0202%
# Epoch 17/30
# 26/26 - train_loss: 1.2240 - train_accuracy: 42.4110%                 - val_loss: 0.6430 - val_accuracy: 52.0202%
# Epoch 18/30
# 26/26 - train_loss: 1.2058 - train_accuracy: 44.4722%                 - val_loss: 0.6497 - val_accuracy: 52.0202%
# Epoch 19/30
# 26/26 - train_loss: 1.2290 - train_accuracy: 41.9738%                 - val_loss: 0.6769 - val_accuracy: 52.0202%
# Epoch 20/30
# 26/26 - train_loss: 1.3100 - train_accuracy: 43.0981%                 - val_loss: 0.7021 - val_accuracy: 52.0202%
# Epoch 21/30
# 26/26 - train_loss: 1.2164 - train_accuracy: 44.2224%                 - val_loss: 0.6506 - val_accuracy: 52.0202%
# Epoch 22/30
# 26/26 - train_loss: 1.2231 - train_accuracy: 43.2230%                 - val_loss: 0.6461 - val_accuracy: 52.0202%
# Epoch 23/30
# 26/26 - train_loss: 1.2166 - train_accuracy: 42.4735%                 - val_loss: 0.6602 - val_accuracy: 52.0202%
# Epoch 24/30
# 26/26 - train_loss: 1.2197 - train_accuracy: 41.8488%                 - val_loss: 0.6712 - val_accuracy: 52.0202%
# Epoch 25/30
# 26/26 - train_loss: 1.2365 - train_accuracy: 39.7876%                 - val_loss: 0.6373 - val_accuracy: 52.0202%
# Epoch 26/30
# 26/26 - train_loss: 1.1943 - train_accuracy: 43.1605%                 - val_loss: 0.6420 - val_accuracy: 52.0202%
# Epoch 27/30
# 26/26 - train_loss: 1.1626 - train_accuracy: 42.4110%                 - val_loss: 0.6596 - val_accuracy: 52.0202%
# Epoch 28/30
# 26/26 - train_loss: 1.1911 - train_accuracy: 43.9725%                 - val_loss: 0.6554 - val_accuracy: 52.0202%
# Epoch 29/30
# 26/26 - train_loss: 1.1611 - train_accuracy: 43.0356%                 - val_loss: 0.6761 - val_accuracy: 52.0202%
# Epoch 30/30
# 26/26 - train_loss: 1.2029 - train_accuracy: 44.3473%                 - val_loss: 0.6703 - val_accuracy: 39.3939%
# Learning Rate: 0.0001, Dropout: 0.2, Num Layers: 12, Test Accuracy: 0.3035
# Epoch 1/30
# 26/26 - train_loss: 1.8552 - train_accuracy: 25.7339%                 - val_loss: 0.8176 - val_accuracy: 13.6364%
# Epoch 2/30
# 26/26 - train_loss: 1.2533 - train_accuracy: 48.7820%                 - val_loss: 0.3527 - val_accuracy: 76.2626%
# Epoch 3/30
# 26/26 - train_loss: 0.3915 - train_accuracy: 85.8838%                 - val_loss: 0.0633 - val_accuracy: 92.9293%
# Epoch 4/30
# 26/26 - train_loss: 0.2189 - train_accuracy: 93.0668%                 - val_loss: 0.0110 - val_accuracy: 93.4343%
# Epoch 5/30
# 26/26 - train_loss: 0.1735 - train_accuracy: 94.7533%                 - val_loss: 0.0021 - val_accuracy: 93.9394%
# Epoch 6/30
# 26/26 - train_loss: 0.0750 - train_accuracy: 95.9400%                 - val_loss: 0.0007 - val_accuracy: 96.9697%
# Epoch 7/30
# 26/26 - train_loss: 0.0518 - train_accuracy: 97.1893%                 - val_loss: 0.0008 - val_accuracy: 95.4545%
# Epoch 8/30
# 26/26 - train_loss: 0.0522 - train_accuracy: 97.7514%                 - val_loss: 0.0004 - val_accuracy: 95.4545%
# Epoch 9/30
# 26/26 - train_loss: 0.0332 - train_accuracy: 98.7508%                 - val_loss: 0.0002 - val_accuracy: 96.9697%
# Epoch 10/30
# 26/26 - train_loss: 0.0242 - train_accuracy: 99.0006%                 - val_loss: 0.0001 - val_accuracy: 94.9495%
# Epoch 11/30
# 26/26 - train_loss: 0.0081 - train_accuracy: 99.7502%                 - val_loss: 0.0001 - val_accuracy: 94.9495%
# Epoch 12/30
# 26/26 - train_loss: 0.0073 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 13/30
# 26/26 - train_loss: 0.0015 - train_accuracy: 100.0000%                 - val_loss: 0.0001 - val_accuracy: 94.9495%
# Epoch 14/30
# 26/26 - train_loss: 0.0209 - train_accuracy: 99.3754%                 - val_loss: 0.0010 - val_accuracy: 94.4444%
# Epoch 15/30
# 26/26 - train_loss: 0.0504 - train_accuracy: 98.5634%                 - val_loss: 0.0001 - val_accuracy: 94.9495%
# Epoch 16/30
# 26/26 - train_loss: 0.0025 - train_accuracy: 99.9375%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 17/30
# 26/26 - train_loss: 0.0005 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 18/30
# 26/26 - train_loss: 0.0003 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 19/30
# 26/26 - train_loss: 0.0002 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 20/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 21/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 22/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 23/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 24/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 25/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 26/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 27/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 28/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 29/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 30/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Learning Rate: 0.0001, Dropout: 0.3, Num Layers: 6, Test Accuracy: 0.9652
# Epoch 1/30
# 26/26 - train_loss: 1.9325 - train_accuracy: 20.4872%                 - val_loss: 0.7651 - val_accuracy: 26.2626%
# Epoch 2/30
# 26/26 - train_loss: 1.7282 - train_accuracy: 20.7995%                 - val_loss: 0.8035 - val_accuracy: 27.2727%
# Epoch 3/30
# 26/26 - train_loss: 1.7052 - train_accuracy: 21.5490%                 - val_loss: 0.8663 - val_accuracy: 26.2626%
# Epoch 4/30
# 26/26 - train_loss: 1.5218 - train_accuracy: 27.2954%                 - val_loss: 0.9927 - val_accuracy: 32.8283%
# Epoch 5/30
# 26/26 - train_loss: 1.3239 - train_accuracy: 42.7858%                 - val_loss: 0.6632 - val_accuracy: 63.1313%
# Epoch 6/30
# 26/26 - train_loss: 1.0643 - train_accuracy: 57.9638%                 - val_loss: 0.3120 - val_accuracy: 64.6465%
# Epoch 7/30
# 26/26 - train_loss: 0.8037 - train_accuracy: 62.1487%                 - val_loss: 0.2310 - val_accuracy: 74.7475%
# Epoch 8/30
# 26/26 - train_loss: 0.4480 - train_accuracy: 85.8838%                 - val_loss: 0.0455 - val_accuracy: 83.3333%
# Epoch 9/30
# 26/26 - train_loss: 0.2854 - train_accuracy: 91.0056%                 - val_loss: 0.0260 - val_accuracy: 90.4040%
# Epoch 10/30
# 26/26 - train_loss: 0.2362 - train_accuracy: 92.5047%                 - val_loss: 0.5255 - val_accuracy: 61.6162%
# Epoch 11/30
# 26/26 - train_loss: 0.4172 - train_accuracy: 86.3210%                 - val_loss: 0.0322 - val_accuracy: 90.4040%
# Epoch 12/30
# 26/26 - train_loss: 0.1893 - train_accuracy: 94.5659%                 - val_loss: 0.0147 - val_accuracy: 92.9293%
# Epoch 13/30
# 26/26 - train_loss: 0.1396 - train_accuracy: 94.8782%                 - val_loss: 0.0046 - val_accuracy: 94.9495%
# Epoch 14/30
# 26/26 - train_loss: 0.0909 - train_accuracy: 96.7520%                 - val_loss: 0.0025 - val_accuracy: 96.9697%
# Epoch 15/30
# 26/26 - train_loss: 0.0683 - train_accuracy: 98.0012%                 - val_loss: 0.0020 - val_accuracy: 95.4545%
# Epoch 16/30
# 26/26 - train_loss: 0.0602 - train_accuracy: 97.9388%                 - val_loss: 0.0011 - val_accuracy: 95.9596%
# Epoch 17/30
# 26/26 - train_loss: 0.0445 - train_accuracy: 98.3760%                 - val_loss: 0.0007 - val_accuracy: 95.4545%
# Epoch 18/30
# 26/26 - train_loss: 0.0406 - train_accuracy: 98.3760%                 - val_loss: 0.0022 - val_accuracy: 94.4444%
# Epoch 19/30
# 26/26 - train_loss: 0.0496 - train_accuracy: 98.1886%                 - val_loss: 0.9136 - val_accuracy: 77.7778%
# Epoch 20/30
# 26/26 - train_loss: 0.3797 - train_accuracy: 89.0693%                 - val_loss: 0.0169 - val_accuracy: 93.9394%
# Epoch 21/30
# 26/26 - train_loss: 0.1196 - train_accuracy: 96.9394%                 - val_loss: 0.0006 - val_accuracy: 92.9293%
# Epoch 22/30
# 26/26 - train_loss: 0.0585 - train_accuracy: 98.5634%                 - val_loss: 0.0002 - val_accuracy: 94.9495%
# Epoch 23/30
# 26/26 - train_loss: 0.0291 - train_accuracy: 99.1255%                 - val_loss: 0.0003 - val_accuracy: 94.9495%
# Epoch 24/30
# 26/26 - train_loss: 0.0343 - train_accuracy: 98.8132%                 - val_loss: 0.0001 - val_accuracy: 94.4444%
# Epoch 25/30
# 26/26 - train_loss: 0.0413 - train_accuracy: 98.6883%                 - val_loss: 0.0005 - val_accuracy: 95.9596%
# Epoch 26/30
# 26/26 - train_loss: 0.0126 - train_accuracy: 99.6252%                 - val_loss: 0.0003 - val_accuracy: 96.4646%
# Epoch 27/30
# 26/26 - train_loss: 0.0227 - train_accuracy: 99.4379%                 - val_loss: 0.0001 - val_accuracy: 96.4646%
# Epoch 28/30
# 26/26 - train_loss: 0.0110 - train_accuracy: 99.6877%                 - val_loss: 0.0001 - val_accuracy: 95.9596%
# Epoch 29/30
# 26/26 - train_loss: 0.0420 - train_accuracy: 99.4379%                 - val_loss: 0.0002 - val_accuracy: 95.9596%
# Epoch 30/30
# 26/26 - train_loss: 0.0311 - train_accuracy: 99.2505%                 - val_loss: 0.0005 - val_accuracy: 93.9394%
# Learning Rate: 0.0001, Dropout: 0.3, Num Layers: 12, Test Accuracy: 0.9552
# Epoch 1/30
# 26/26 - train_loss: 1.6950 - train_accuracy: 32.2299%                 - val_loss: 0.7105 - val_accuracy: 49.4949%
# Epoch 2/30
# 26/26 - train_loss: 1.0672 - train_accuracy: 57.6515%                 - val_loss: 0.2459 - val_accuracy: 68.6869%
# Epoch 3/30
# 26/26 - train_loss: 0.4408 - train_accuracy: 85.1343%                 - val_loss: 0.0602 - val_accuracy: 92.4242%
# Epoch 4/30
# 26/26 - train_loss: 0.2121 - train_accuracy: 92.0675%                 - val_loss: 0.1121 - val_accuracy: 95.4545%
# Epoch 5/30
# 26/26 - train_loss: 0.1160 - train_accuracy: 95.1280%                 - val_loss: 0.0379 - val_accuracy: 95.9596%
# Epoch 6/30
# 26/26 - train_loss: 0.0847 - train_accuracy: 95.8151%                 - val_loss: 0.0178 - val_accuracy: 95.9596%
# Epoch 7/30
# 26/26 - train_loss: 0.0739 - train_accuracy: 96.5022%                 - val_loss: 0.0048 - val_accuracy: 95.9596%
# Epoch 8/30
# 26/26 - train_loss: 0.0526 - train_accuracy: 97.9388%                 - val_loss: 0.0023 - val_accuracy: 95.9596%
# Epoch 9/30
# 26/26 - train_loss: 0.0528 - train_accuracy: 97.6889%                 - val_loss: 0.0010 - val_accuracy: 96.4646%
# Epoch 10/30
# 26/26 - train_loss: 0.0245 - train_accuracy: 99.0006%                 - val_loss: 0.0007 - val_accuracy: 96.9697%
# Epoch 11/30
# 26/26 - train_loss: 0.0115 - train_accuracy: 99.7502%                 - val_loss: 0.0005 - val_accuracy: 95.4545%
# Epoch 12/30
# 26/26 - train_loss: 0.0096 - train_accuracy: 99.6252%                 - val_loss: 0.0008 - val_accuracy: 97.9798%
# Epoch 13/30
# 26/26 - train_loss: 0.0023 - train_accuracy: 100.0000%                 - val_loss: 0.0005 - val_accuracy: 98.4848%
# Epoch 14/30
# 26/26 - train_loss: 0.0012 - train_accuracy: 100.0000%                 - val_loss: 0.0002 - val_accuracy: 98.4848%
# Epoch 15/30
# 26/26 - train_loss: 0.0006 - train_accuracy: 100.0000%                 - val_loss: 0.0002 - val_accuracy: 98.4848%
# Epoch 16/30
# 26/26 - train_loss: 0.0004 - train_accuracy: 100.0000%                 - val_loss: 0.0001 - val_accuracy: 97.9798%
# Epoch 17/30
# 26/26 - train_loss: 0.0003 - train_accuracy: 100.0000%                 - val_loss: 0.0001 - val_accuracy: 98.4848%
# Epoch 18/30
# 26/26 - train_loss: 0.0002 - train_accuracy: 100.0000%                 - val_loss: 0.0001 - val_accuracy: 98.4848%
# Epoch 19/30
# 26/26 - train_loss: 0.0002 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 20/30
# 26/26 - train_loss: 0.0002 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 21/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 22/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 23/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 24/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 25/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 26/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 27/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 28/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 29/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 30/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Learning Rate: 5e-05, Dropout: 0.1, Num Layers: 6, Test Accuracy: 0.9751
# Epoch 1/30
# 26/26 - train_loss: 1.8055 - train_accuracy: 23.1730%                 - val_loss: 0.8321 - val_accuracy: 18.1818%
# Epoch 2/30
# 26/26 - train_loss: 1.5592 - train_accuracy: 34.9781%                 - val_loss: 0.5513 - val_accuracy: 46.9697%
# Epoch 3/30
# 26/26 - train_loss: 0.8776 - train_accuracy: 69.4566%                 - val_loss: 1.5540 - val_accuracy: 53.5354%
# Epoch 4/30
# 26/26 - train_loss: 0.9300 - train_accuracy: 67.0206%                 - val_loss: 0.1228 - val_accuracy: 77.2727%
# Epoch 5/30
# 26/26 - train_loss: 0.2878 - train_accuracy: 89.5066%                 - val_loss: 0.0210 - val_accuracy: 92.9293%
# Epoch 6/30
# 26/26 - train_loss: 0.1295 - train_accuracy: 95.3154%                 - val_loss: 0.0079 - val_accuracy: 93.4343%
# Epoch 7/30
# 26/26 - train_loss: 0.0943 - train_accuracy: 96.1899%                 - val_loss: 0.0020 - val_accuracy: 93.4343%
# Epoch 8/30
# 26/26 - train_loss: 0.0656 - train_accuracy: 97.3142%                 - val_loss: 0.0012 - val_accuracy: 94.4444%
# Epoch 9/30
# 26/26 - train_loss: 0.0543 - train_accuracy: 98.0012%                 - val_loss: 0.0093 - val_accuracy: 90.4040%
# Epoch 10/30
# 26/26 - train_loss: 0.0938 - train_accuracy: 96.6271%                 - val_loss: 0.0003 - val_accuracy: 95.4545%
# Epoch 11/30
# 26/26 - train_loss: 0.0306 - train_accuracy: 98.6259%                 - val_loss: 0.0002 - val_accuracy: 95.9596%
# Epoch 12/30
# 26/26 - train_loss: 0.0406 - train_accuracy: 98.5634%                 - val_loss: 0.0009 - val_accuracy: 93.9394%
# Epoch 13/30
# 26/26 - train_loss: 0.0457 - train_accuracy: 98.4385%                 - val_loss: 0.0003 - val_accuracy: 95.4545%
# Epoch 14/30
# 26/26 - train_loss: 0.0284 - train_accuracy: 99.0006%                 - val_loss: 0.0002 - val_accuracy: 94.9495%
# Epoch 15/30
# 26/26 - train_loss: 0.0217 - train_accuracy: 99.1880%                 - val_loss: 0.0002 - val_accuracy: 95.9596%
# Epoch 16/30
# 26/26 - train_loss: 0.0121 - train_accuracy: 99.5628%                 - val_loss: 0.0004 - val_accuracy: 95.9596%
# Epoch 17/30
# 26/26 - train_loss: 0.0087 - train_accuracy: 99.7502%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 18/30
# 26/26 - train_loss: 0.0070 - train_accuracy: 99.7502%                 - val_loss: 0.0010 - val_accuracy: 93.4343%
# Epoch 19/30
# 26/26 - train_loss: 0.0304 - train_accuracy: 98.7508%                 - val_loss: 0.0003 - val_accuracy: 95.9596%
# Epoch 20/30
# 26/26 - train_loss: 0.0063 - train_accuracy: 99.8126%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 21/30
# 26/26 - train_loss: 0.0004 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 22/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 23/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.4646%
# Epoch 24/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.4646%
# Epoch 25/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.4646%
# Epoch 26/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.4646%
# Epoch 27/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.4646%
# Epoch 28/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 29/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.4646%
# Epoch 30/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.4646%
# Learning Rate: 5e-05, Dropout: 0.1, Num Layers: 12, Test Accuracy: 0.9751
# Epoch 1/30
# 26/26 - train_loss: 1.5666 - train_accuracy: 35.7277%                 - val_loss: 0.5413 - val_accuracy: 55.0505%
# Epoch 2/30
# 26/26 - train_loss: 0.9752 - train_accuracy: 60.7121%                 - val_loss: 0.2974 - val_accuracy: 80.8081%
# Epoch 3/30
# 26/26 - train_loss: 0.4005 - train_accuracy: 86.6334%                 - val_loss: 0.0656 - val_accuracy: 94.4444%
# Epoch 4/30
# 26/26 - train_loss: 0.1733 - train_accuracy: 93.3167%                 - val_loss: 0.0410 - val_accuracy: 93.4343%
# Epoch 5/30
# 26/26 - train_loss: 0.0962 - train_accuracy: 95.6277%                 - val_loss: 0.0211 - val_accuracy: 95.9596%
# Epoch 6/30
# 26/26 - train_loss: 0.0712 - train_accuracy: 96.9394%                 - val_loss: 0.0037 - val_accuracy: 97.4747%
# Epoch 7/30
# 26/26 - train_loss: 0.0527 - train_accuracy: 98.0012%                 - val_loss: 0.0031 - val_accuracy: 97.4747%
# Epoch 8/30
# 26/26 - train_loss: 0.0506 - train_accuracy: 98.1886%                 - val_loss: 0.1062 - val_accuracy: 93.9394%
# Epoch 9/30
# 26/26 - train_loss: 0.0579 - train_accuracy: 97.9388%                 - val_loss: 0.0004 - val_accuracy: 94.4444%
# Epoch 10/30
# 26/26 - train_loss: 0.0339 - train_accuracy: 98.7508%                 - val_loss: 0.0095 - val_accuracy: 94.9495%
# Epoch 11/30
# 26/26 - train_loss: 0.0192 - train_accuracy: 99.1255%                 - val_loss: 0.0003 - val_accuracy: 96.9697%
# Epoch 12/30
# 26/26 - train_loss: 0.0079 - train_accuracy: 99.7502%                 - val_loss: 0.0003 - val_accuracy: 97.9798%
# Epoch 13/30
# 26/26 - train_loss: 0.0025 - train_accuracy: 100.0000%                 - val_loss: 0.0002 - val_accuracy: 98.4848%
# Epoch 14/30
# 26/26 - train_loss: 0.0019 - train_accuracy: 100.0000%                 - val_loss: 0.0002 - val_accuracy: 97.9798%
# Epoch 15/30
# 26/26 - train_loss: 0.0334 - train_accuracy: 98.9382%                 - val_loss: 0.0048 - val_accuracy: 91.9192%
# Epoch 16/30
# 26/26 - train_loss: 0.1060 - train_accuracy: 96.6271%                 - val_loss: 0.0006 - val_accuracy: 96.9697%
# Epoch 17/30
# 26/26 - train_loss: 0.0146 - train_accuracy: 99.6877%                 - val_loss: 0.0001 - val_accuracy: 96.4646%
# Epoch 18/30
# 26/26 - train_loss: 0.0043 - train_accuracy: 99.8751%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 19/30
# 26/26 - train_loss: 0.0021 - train_accuracy: 100.0000%                 - val_loss: 0.0001 - val_accuracy: 98.4848%
# Epoch 20/30
# 26/26 - train_loss: 0.0010 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 21/30
# 26/26 - train_loss: 0.0004 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 22/30
# 26/26 - train_loss: 0.0003 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 23/30
# 26/26 - train_loss: 0.0002 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 24/30
# 26/26 - train_loss: 0.0002 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 25/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 26/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 27/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Epoch 28/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 29/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.9899%
# Epoch 30/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 98.4848%
# Learning Rate: 5e-05, Dropout: 0.2, Num Layers: 6, Test Accuracy: 0.9751
# Epoch 1/30
# 26/26 - train_loss: 1.7631 - train_accuracy: 22.1112%                 - val_loss: 0.7501 - val_accuracy: 34.3434%
# Epoch 2/30
# 26/26 - train_loss: 1.5985 - train_accuracy: 29.4191%                 - val_loss: 0.8436 - val_accuracy: 31.3131%
# Epoch 3/30
# 26/26 - train_loss: 0.9959 - train_accuracy: 59.6502%                 - val_loss: 0.4287 - val_accuracy: 63.6364%
# Epoch 4/30
# 26/26 - train_loss: 0.4478 - train_accuracy: 82.8232%                 - val_loss: 0.0557 - val_accuracy: 88.8889%
# Epoch 5/30
# 26/26 - train_loss: 0.1922 - train_accuracy: 92.6296%                 - val_loss: 0.0258 - val_accuracy: 93.4343%
# Epoch 6/30
# 26/26 - train_loss: 0.0929 - train_accuracy: 96.3773%                 - val_loss: 0.0351 - val_accuracy: 93.9394%
# Epoch 7/30
# 26/26 - train_loss: 0.1086 - train_accuracy: 95.8151%                 - val_loss: 0.0772 - val_accuracy: 91.9192%
# Epoch 8/30
# 26/26 - train_loss: 0.1083 - train_accuracy: 95.2530%                 - val_loss: 0.0040 - val_accuracy: 93.9394%
# Epoch 9/30
# 26/26 - train_loss: 0.0659 - train_accuracy: 96.6896%                 - val_loss: 0.0010 - val_accuracy: 95.4545%
# Epoch 10/30
# 26/26 - train_loss: 0.0490 - train_accuracy: 98.0637%                 - val_loss: 0.0523 - val_accuracy: 92.9293%
# Epoch 11/30
# 26/26 - train_loss: 0.0439 - train_accuracy: 98.3136%                 - val_loss: 0.0452 - val_accuracy: 93.4343%
# Epoch 12/30
# 26/26 - train_loss: 0.0744 - train_accuracy: 97.5640%                 - val_loss: 0.0192 - val_accuracy: 97.4747%
# Epoch 13/30
# 26/26 - train_loss: 0.0234 - train_accuracy: 99.2505%                 - val_loss: 0.0004 - val_accuracy: 96.9697%
# Epoch 14/30
# 26/26 - train_loss: 0.0142 - train_accuracy: 99.5628%                 - val_loss: 0.0029 - val_accuracy: 94.4444%
# Epoch 15/30
# 26/26 - train_loss: 0.0289 - train_accuracy: 98.8757%                 - val_loss: 0.0004 - val_accuracy: 95.4545%
# Epoch 16/30
# 26/26 - train_loss: 0.0259 - train_accuracy: 99.1880%                 - val_loss: 0.0024 - val_accuracy: 96.9697%
# Epoch 17/30
# 26/26 - train_loss: 0.0084 - train_accuracy: 99.8126%                 - val_loss: 0.0004 - val_accuracy: 96.4646%
# Epoch 18/30
# 26/26 - train_loss: 0.0068 - train_accuracy: 99.8751%                 - val_loss: 0.1243 - val_accuracy: 95.4545%
# Epoch 19/30
# 26/26 - train_loss: 0.0073 - train_accuracy: 99.6877%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 20/30
# 26/26 - train_loss: 0.0008 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 21/30
# 26/26 - train_loss: 0.0005 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 22/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 23/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 24/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 25/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 26/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 27/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 28/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 29/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 30/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Learning Rate: 5e-05, Dropout: 0.2, Num Layers: 12, Test Accuracy: 0.9751
# Epoch 1/30
# 26/26 - train_loss: 1.6804 - train_accuracy: 27.6077%                 - val_loss: 0.8862 - val_accuracy: 26.7677%
# Epoch 2/30
# 26/26 - train_loss: 1.3126 - train_accuracy: 46.9082%                 - val_loss: 0.4001 - val_accuracy: 69.6970%
# Epoch 3/30
# 26/26 - train_loss: 0.5869 - train_accuracy: 80.8245%                 - val_loss: 0.0592 - val_accuracy: 87.8788%
# Epoch 4/30
# 26/26 - train_loss: 0.2757 - train_accuracy: 89.4441%                 - val_loss: 0.0156 - val_accuracy: 93.9394%
# Epoch 5/30
# 26/26 - train_loss: 0.1074 - train_accuracy: 95.6902%                 - val_loss: 0.0010 - val_accuracy: 93.9394%
# Epoch 6/30
# 26/26 - train_loss: 0.0828 - train_accuracy: 96.3148%                 - val_loss: 0.0009 - val_accuracy: 95.4545%
# Epoch 7/30
# 26/26 - train_loss: 0.0632 - train_accuracy: 97.5640%                 - val_loss: 0.0007 - val_accuracy: 95.4545%
# Epoch 8/30
# 26/26 - train_loss: 0.0676 - train_accuracy: 97.6889%                 - val_loss: 0.0039 - val_accuracy: 95.4545%
# Epoch 9/30
# 26/26 - train_loss: 0.0559 - train_accuracy: 98.1262%                 - val_loss: 0.0002 - val_accuracy: 95.4545%
# Epoch 10/30
# 26/26 - train_loss: 0.0287 - train_accuracy: 99.1880%                 - val_loss: 0.0002 - val_accuracy: 95.4545%
# Epoch 11/30
# 26/26 - train_loss: 0.0697 - train_accuracy: 97.6265%                 - val_loss: 0.0008 - val_accuracy: 94.9495%
# Epoch 12/30
# 26/26 - train_loss: 0.0303 - train_accuracy: 98.6259%                 - val_loss: 0.0004 - val_accuracy: 96.4646%
# Epoch 13/30
# 26/26 - train_loss: 0.0131 - train_accuracy: 99.4379%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 14/30
# 26/26 - train_loss: 0.0043 - train_accuracy: 99.8751%                 - val_loss: 0.0001 - val_accuracy: 97.4747%
# Epoch 15/30
# 26/26 - train_loss: 0.0045 - train_accuracy: 99.8751%                 - val_loss: 0.0001 - val_accuracy: 96.9697%
# Epoch 16/30
# 26/26 - train_loss: 0.0066 - train_accuracy: 99.8126%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 17/30
# 26/26 - train_loss: 0.0017 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 18/30
# 26/26 - train_loss: 0.0126 - train_accuracy: 99.5003%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 19/30
# 26/26 - train_loss: 0.0026 - train_accuracy: 99.9375%                 - val_loss: 0.0000 - val_accuracy: 95.4545%
# Epoch 20/30
# 26/26 - train_loss: 0.0020 - train_accuracy: 99.9375%                 - val_loss: 0.0000 - val_accuracy: 96.4646%
# Epoch 21/30
# 26/26 - train_loss: 0.0006 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 22/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 23/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 24/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 25/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 26/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 27/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 28/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.4646%
# Epoch 29/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 30/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Learning Rate: 5e-05, Dropout: 0.3, Num Layers: 6, Test Accuracy: 0.9701
# Epoch 1/30
# 26/26 - train_loss: 1.7618 - train_accuracy: 22.7983%                 - val_loss: 0.9145 - val_accuracy: 12.6263%
# Epoch 2/30
# 26/26 - train_loss: 1.5776 - train_accuracy: 31.5428%                 - val_loss: 0.5244 - val_accuracy: 57.5758%
# Epoch 3/30
# 26/26 - train_loss: 0.8376 - train_accuracy: 67.9575%                 - val_loss: 0.0377 - val_accuracy: 89.3939%
# Epoch 4/30
# 26/26 - train_loss: 0.2605 - train_accuracy: 91.0056%                 - val_loss: 0.0524 - val_accuracy: 90.9091%
# Epoch 5/30
# 26/26 - train_loss: 0.1491 - train_accuracy: 94.6908%                 - val_loss: 0.0063 - val_accuracy: 95.9596%
# Epoch 6/30
# 26/26 - train_loss: 0.0928 - train_accuracy: 96.6896%                 - val_loss: 0.0327 - val_accuracy: 95.9596%
# Epoch 7/30
# 26/26 - train_loss: 0.1076 - train_accuracy: 95.3779%                 - val_loss: 0.0042 - val_accuracy: 96.4646%
# Epoch 8/30
# 26/26 - train_loss: 0.0798 - train_accuracy: 96.6896%                 - val_loss: 0.0077 - val_accuracy: 95.4545%
# Epoch 9/30
# 26/26 - train_loss: 0.0539 - train_accuracy: 97.5640%                 - val_loss: 0.0007 - val_accuracy: 96.4646%
# Epoch 10/30
# 26/26 - train_loss: 0.0507 - train_accuracy: 98.1262%                 - val_loss: 0.0006 - val_accuracy: 97.9798%
# Epoch 11/30
# 26/26 - train_loss: 0.0354 - train_accuracy: 98.9382%                 - val_loss: 0.0007 - val_accuracy: 95.4545%
# Epoch 12/30
# 26/26 - train_loss: 0.0605 - train_accuracy: 97.5016%                 - val_loss: 0.0001 - val_accuracy: 96.9697%
# Epoch 13/30
# 26/26 - train_loss: 0.0244 - train_accuracy: 98.8132%                 - val_loss: 0.0072 - val_accuracy: 96.9697%
# Epoch 14/30
# 26/26 - train_loss: 0.0133 - train_accuracy: 99.3754%                 - val_loss: 0.0001 - val_accuracy: 95.9596%
# Epoch 15/30
# 26/26 - train_loss: 0.0108 - train_accuracy: 99.5628%                 - val_loss: 0.0001 - val_accuracy: 95.4545%
# Epoch 16/30
# 26/26 - train_loss: 0.0503 - train_accuracy: 98.3760%                 - val_loss: 0.0001 - val_accuracy: 96.4646%
# Epoch 17/30
# 26/26 - train_loss: 0.0126 - train_accuracy: 99.6877%                 - val_loss: 0.0001 - val_accuracy: 96.9697%
# Epoch 18/30
# 26/26 - train_loss: 0.0013 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 19/30
# 26/26 - train_loss: 0.0003 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 96.9697%
# Epoch 20/30
# 26/26 - train_loss: 0.0002 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 21/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 22/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 23/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.4747%
# Epoch 24/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 25/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 26/30
# 26/26 - train_loss: 0.0001 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 27/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 28/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 29/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Epoch 30/30
# 26/26 - train_loss: 0.0000 - train_accuracy: 100.0000%                 - val_loss: 0.0000 - val_accuracy: 97.9798%
# Learning Rate: 5e-05, Dropout: 0.3, Num Layers: 12, Test Accuracy: 0.9602
# Epoch 1/30
# 26/26 - train_loss: 1.6658 - train_accuracy: 24.1099%                 - val_loss: 0.7236 - val_accuracy: 27.2727%
# Epoch 2/30
# 26/26 - train_loss: 1.5979 - train_accuracy: 30.7308%                 - val_loss: 0.7135 - val_accuracy: 40.9091%
# Epoch 3/30
# 26/26 - train_loss: 1.5260 - train_accuracy: 40.4747%                 - val_loss: 0.7325 - val_accuracy: 65.6566%
# Epoch 4/30
# 26/26 - train_loss: 1.3938 - train_accuracy: 57.4016%                 - val_loss: 0.6393 - val_accuracy: 70.2020%
# Epoch 5/30
# 26/26 - train_loss: 1.1593 - train_accuracy: 65.3966%                 - val_loss: 0.5222 - val_accuracy: 74.2424%
# Epoch 6/30
# 26/26 - train_loss: 0.9040 - train_accuracy: 72.6421%                 - val_loss: 0.3459 - val_accuracy: 77.2727%
# Epoch 7/30
# 26/26 - train_loss: 0.6666 - train_accuracy: 80.3873%                 - val_loss: 0.2182 - val_accuracy: 82.8283%
# Epoch 8/30
# 26/26 - train_loss: 0.4955 - train_accuracy: 86.5709%                 - val_loss: 0.1564 - val_accuracy: 91.4141%
# Epoch 9/30
# 26/26 - train_loss: 0.3649 - train_accuracy: 88.1949%                 - val_loss: 0.1021 - val_accuracy: 92.9293%
# Epoch 10/30
# 26/26 - train_loss: 0.2860 - train_accuracy: 90.9432%                 - val_loss: 0.0517 - val_accuracy: 93.4343%
# Epoch 11/30
# 26/26 - train_loss: 0.2236 - train_accuracy: 92.6921%                 - val_loss: 0.0349 - val_accuracy: 93.4343%
# Epoch 12/30
# 26/26 - train_loss: 0.1860 - train_accuracy: 93.8164%                 - val_loss: 0.0263 - val_accuracy: 92.9293%
# Epoch 13/30
# 26/26 - train_loss: 0.1731 - train_accuracy: 93.5665%                 - val_loss: 0.0268 - val_accuracy: 93.9394%
# Epoch 14/30
# ...
# Epoch 5/30
# 26/26 - train_loss: 1.3366 - train_accuracy: 55.5903%                 - val_loss: 0.4992 - val_accuracy: 61.6162%
# Epoch 6/30
# 26/26 - train_loss: 1.1020 - train_accuracy: 67.7077%                 - val_loss: 0.3469 - val_accuracy: 70.2020%
# Epoch 7/30
# 26/26 - train_loss: 0.8480 - train_accuracy: 76.1399%                 - val_loss: 0.2102 - val_accuracy: 78.7879%
# Epoch 8/30
# 26/26 - train_loss: 0.6207 - train_accuracy: 83.1355%                 - val_loss: 0.0948 - val_accuracy: 81.8182%
# Epoch 9/30
# 26/26 - train_loss: 0.4486 - train_accuracy: 86.5709%                 - val_loss: 0.0526 - val_accuracy: 88.3838%
# Epoch 10/30
# 26/26 - train_loss: 0.3176 - train_accuracy: 88.9444%                 - val_loss: 0.0298 - val_accuracy: 92.4242%
# Epoch 11/30
# 26/26 - train_loss: 0.2220 - train_accuracy: 92.6921%                 - val_loss: 0.0177 - val_accuracy: 92.4242%
# Epoch 12/30
# 26/26 - train_loss: 0.1832 - train_accuracy: 94.6284%                 - val_loss: 0.0157 - val_accuracy: 94.4444%
# Epoch 13/30
# 26/26 - train_loss: 0.1516 - train_accuracy: 95.3154%                 - val_loss: 0.0062 - val_accuracy: 94.4444%
# Epoch 14/30
# 26/26 - train_loss: 0.1376 - train_accuracy: 95.1280%                 - val_loss: 0.0038 - val_accuracy: 93.9394%
# Epoch 15/30
# 26/26 - train_loss: 0.1095 - train_accuracy: 95.7527%                 - val_loss: 0.0045 - val_accuracy: 94.4444%
# Epoch 16/30
# 26/26 - train_loss: 0.0924 - train_accuracy: 96.5646%                 - val_loss: 0.0033 - val_accuracy: 94.4444%
# Epoch 17/30
# 26/26 - train_loss: 0.0770 - train_accuracy: 96.8145%                 - val_loss: 0.0036 - val_accuracy: 95.4545%
# Epoch 18/30
# 26/26 - train_loss: 0.0670 - train_accuracy: 97.5016%                 - val_loss: 0.0029 - val_accuracy: 93.9394%
# Epoch 19/30
# 26/26 - train_loss: 0.0646 - train_accuracy: 97.6889%                 - val_loss: 0.0029 - val_accuracy: 94.9495%
# Epoch 20/30
# 26/26 - train_loss: 0.0568 - train_accuracy: 97.3766%                 - val_loss: 0.0008 - val_accuracy: 94.4444%
# Epoch 21/30
# 26/26 - train_loss: 0.0864 - train_accuracy: 98.0637%                 - val_loss: 0.0014 - val_accuracy: 94.9495%
# Epoch 22/30
# 26/26 - train_loss: 0.1297 - train_accuracy: 95.6277%                 - val_loss: 0.0006 - val_accuracy: 94.4444%
# Epoch 23/30
# 26/26 - train_loss: 0.0438 - train_accuracy: 98.6883%                 - val_loss: 0.0007 - val_accuracy: 95.4545%
# Epoch 24/30
# 26/26 - train_loss: 0.0345 - train_accuracy: 98.6883%                 - val_loss: 0.0008 - val_accuracy: 94.9495%
# Epoch 25/30
# 26/26 - train_loss: 0.0314 - train_accuracy: 99.0006%                 - val_loss: 0.0006 - val_accuracy: 95.9596%
# Epoch 26/30
# 26/26 - train_loss: 0.0300 - train_accuracy: 99.0631%                 - val_loss: 0.0009 - val_accuracy: 94.9495%
# Epoch 27/30
# 26/26 - train_loss: 0.0294 - train_accuracy: 99.0006%                 - val_loss: 0.0007 - val_accuracy: 95.9596%
# Epoch 28/30
# 26/26 - train_loss: 0.0207 - train_accuracy: 99.4379%                 - val_loss: 0.0004 - val_accuracy: 95.9596%
# Epoch 29/30
# 26/26 - train_loss: 0.0180 - train_accuracy: 99.5628%                 - val_loss: 0.0002 - val_accuracy: 96.4646%
# Epoch 30/30
# 26/26 - train_loss: 0.0194 - train_accuracy: 99.5628%                 - val_loss: 0.0004 - val_accuracy: 95.9596%
# Learning Rate: 1e-05, Dropout: 0.2, Num Layers: 6, Test Accuracy: 0.9701
# Epoch 1/30
# 26/26 - train_loss: 1.6495 - train_accuracy: 27.7951%                 - val_loss: 0.8241 - val_accuracy: 22.7273%
# Epoch 2/30
# 26/26 - train_loss: 1.5945 - train_accuracy: 34.1661%                 - val_loss: 0.7212 - val_accuracy: 41.4141%
# Epoch 3/30
# 26/26 - train_loss: 1.4866 - train_accuracy: 43.1605%                 - val_loss: 0.6567 - val_accuracy: 64.1414%
# Epoch 4/30
# 26/26 - train_loss: 1.1799 - train_accuracy: 59.9001%                 - val_loss: 0.3910 - val_accuracy: 69.1919%
# Epoch 5/30
# 26/26 - train_loss: 0.8505 - train_accuracy: 75.1405%                 - val_loss: 0.4449 - val_accuracy: 66.1616%
# Epoch 6/30
# 26/26 - train_loss: 0.7781 - train_accuracy: 77.9513%                 - val_loss: 0.1271 - val_accuracy: 88.3838%
# Epoch 7/30
# 26/26 - train_loss: 0.4651 - train_accuracy: 86.8207%                 - val_loss: 0.0584 - val_accuracy: 91.9192%
# Epoch 8/30
# 26/26 - train_loss: 0.3091 - train_accuracy: 91.5053%                 - val_loss: 0.0368 - val_accuracy: 90.4040%
# Epoch 9/30
# 26/26 - train_loss: 0.2537 - train_accuracy: 91.9425%                 - val_loss: 0.0246 - val_accuracy: 89.8990%
# Epoch 10/30
# 26/26 - train_loss: 0.2354 - train_accuracy: 92.2548%                 - val_loss: 0.0706 - val_accuracy: 91.4141%
# Epoch 11/30
# 26/26 - train_loss: 0.1446 - train_accuracy: 95.0656%                 - val_loss: 0.0268 - val_accuracy: 92.9293%
# Epoch 12/30
# 26/26 - train_loss: 0.1281 - train_accuracy: 95.5028%                 - val_loss: 0.0118 - val_accuracy: 96.4646%
# Epoch 13/30
# 26/26 - train_loss: 0.1755 - train_accuracy: 96.3148%                 - val_loss: 0.0148 - val_accuracy: 93.9394%
# Epoch 14/30
# 26/26 - train_loss: 0.2573 - train_accuracy: 91.3179%                 - val_loss: 0.0129 - val_accuracy: 93.4343%
# Epoch 15/30
# 26/26 - train_loss: 0.1123 - train_accuracy: 96.0025%                 - val_loss: 0.0115 - val_accuracy: 93.9394%
# Epoch 16/30
# 26/26 - train_loss: 0.0943 - train_accuracy: 96.2523%                 - val_loss: 0.0040 - val_accuracy: 96.4646%
# Epoch 17/30
# 26/26 - train_loss: 0.0666 - train_accuracy: 97.5640%                 - val_loss: 0.0066 - val_accuracy: 94.9495%
# Epoch 18/30
# 26/26 - train_loss: 0.0751 - train_accuracy: 97.6889%                 - val_loss: 0.0049 - val_accuracy: 94.9495%
# Epoch 19/30
# 26/26 - train_loss: 0.0865 - train_accuracy: 97.2517%                 - val_loss: 0.0117 - val_accuracy: 93.9394%
# Epoch 20/30
# 26/26 - train_loss: 0.0506 - train_accuracy: 98.1262%                 - val_loss: 0.0012 - val_accuracy: 96.4646%
# Epoch 21/30
# 26/26 - train_loss: 0.0537 - train_accuracy: 98.0637%                 - val_loss: 0.0313 - val_accuracy: 94.9495%
# Epoch 22/30
# 26/26 - train_loss: 0.0649 - train_accuracy: 98.2511%                 - val_loss: 0.0330 - val_accuracy: 93.9394%
# Epoch 23/30
# 26/26 - train_loss: 0.2126 - train_accuracy: 93.3167%                 - val_loss: 0.0034 - val_accuracy: 96.9697%
# Epoch 24/30
# 26/26 - train_loss: 0.0557 - train_accuracy: 98.0012%                 - val_loss: 0.0010 - val_accuracy: 96.4646%
# Epoch 25/30
# 26/26 - train_loss: 0.0333 - train_accuracy: 98.8757%                 - val_loss: 0.0009 - val_accuracy: 97.9798%
# Epoch 26/30
# 26/26 - train_loss: 0.0233 - train_accuracy: 99.2505%                 - val_loss: 0.0005 - val_accuracy: 95.9596%
# Epoch 27/30
# 26/26 - train_loss: 0.0237 - train_accuracy: 99.1880%                 - val_loss: 0.0005 - val_accuracy: 98.4848%
# Epoch 28/30
# 26/26 - train_loss: 0.0130 - train_accuracy: 99.8751%                 - val_loss: 0.0004 - val_accuracy: 97.9798%
# Epoch 29/30
# 26/26 - train_loss: 0.0231 - train_accuracy: 99.9375%                 - val_loss: 0.0064 - val_accuracy: 95.9596%
# Epoch 30/30
# 26/26 - train_loss: 0.0960 - train_accuracy: 96.4397%                 - val_loss: 0.0039 - val_accuracy: 96.4646%
# Learning Rate: 1e-05, Dropout: 0.2, Num Layers: 12, Test Accuracy: 0.9701
# Epoch 1/30
# 26/26 - train_loss: 1.6551 - train_accuracy: 27.8576%                 - val_loss: 0.7566 - val_accuracy: 29.2929%
# Epoch 2/30
# 26/26 - train_loss: 1.6273 - train_accuracy: 29.4191%                 - val_loss: 0.7397 - val_accuracy: 42.4242%
# Epoch 3/30
# 26/26 - train_loss: 1.5632 - train_accuracy: 41.1618%                 - val_loss: 0.6627 - val_accuracy: 41.9192%
# Epoch 4/30
# 26/26 - train_loss: 1.4991 - train_accuracy: 41.6615%                 - val_loss: 0.5684 - val_accuracy: 51.0101%
# Epoch 5/30
# 26/26 - train_loss: 1.2415 - train_accuracy: 62.0862%                 - val_loss: 0.5202 - val_accuracy: 70.7071%
# Epoch 6/30
# 26/26 - train_loss: 1.0523 - train_accuracy: 68.4572%                 - val_loss: 0.3951 - val_accuracy: 77.2727%
# Epoch 7/30
# 26/26 - train_loss: 0.8548 - train_accuracy: 73.4541%                 - val_loss: 0.3188 - val_accuracy: 84.8485%
# Epoch 8/30
# 26/26 - train_loss: 0.7690 - train_accuracy: 79.6377%                 - val_loss: 0.1683 - val_accuracy: 88.3838%
# Epoch 9/30
# 26/26 - train_loss: 0.4999 - train_accuracy: 87.1955%                 - val_loss: 0.0689 - val_accuracy: 88.8889%
# Epoch 10/30
# 26/26 - train_loss: 0.3564 - train_accuracy: 89.0069%                 - val_loss: 0.0689 - val_accuracy: 92.4242%
# Epoch 11/30
# 26/26 - train_loss: 0.3193 - train_accuracy: 91.8801%                 - val_loss: 0.0480 - val_accuracy: 93.9394%
# Epoch 12/30
# 26/26 - train_loss: 0.2776 - train_accuracy: 90.9432%                 - val_loss: 0.0408 - val_accuracy: 93.9394%
# Epoch 13/30
# 26/26 - train_loss: 0.2028 - train_accuracy: 93.3167%                 - val_loss: 0.0430 - val_accuracy: 96.4646%
# Epoch 14/30
# 26/26 - train_loss: 0.1593 - train_accuracy: 95.3779%                 - val_loss: 0.0333 - val_accuracy: 95.9596%
# Epoch 15/30
# 26/26 - train_loss: 0.1357 - train_accuracy: 95.8151%                 - val_loss: 0.0184 - val_accuracy: 93.9394%
# Epoch 16/30
# 26/26 - train_loss: 0.1221 - train_accuracy: 95.8776%                 - val_loss: 0.0123 - val_accuracy: 96.4646%
# Epoch 17/30
# 26/26 - train_loss: 0.1045 - train_accuracy: 96.6271%                 - val_loss: 0.0072 - val_accuracy: 93.9394%
# Epoch 18/30
# 26/26 - train_loss: 0.0867 - train_accuracy: 96.6896%                 - val_loss: 0.0078 - val_accuracy: 94.9495%
# Epoch 19/30
# 26/26 - train_loss: 0.0785 - train_accuracy: 97.1893%                 - val_loss: 0.0073 - val_accuracy: 94.9495%
# Epoch 20/30
# 26/26 - train_loss: 0.0652 - train_accuracy: 97.8763%                 - val_loss: 0.0025 - val_accuracy: 93.9394%
# Epoch 21/30
# 26/26 - train_loss: 0.0678 - train_accuracy: 97.0019%                 - val_loss: 0.0020 - val_accuracy: 94.9495%
# Epoch 22/30
# 26/26 - train_loss: 0.0696 - train_accuracy: 97.2517%                 - val_loss: 0.0126 - val_accuracy: 94.4444%
# Epoch 23/30
# 26/26 - train_loss: 0.0517 - train_accuracy: 98.2511%                 - val_loss: 0.0025 - val_accuracy: 95.4545%
# Epoch 24/30
# 26/26 - train_loss: 0.0490 - train_accuracy: 98.2511%                 - val_loss: 0.0056 - val_accuracy: 96.4646%
# Epoch 25/30
# 26/26 - train_loss: 0.0457 - train_accuracy: 98.1886%                 - val_loss: 0.0008 - val_accuracy: 96.4646%
# Epoch 26/30
# 26/26 - train_loss: 0.0328 - train_accuracy: 99.1255%                 - val_loss: 0.0011 - val_accuracy: 96.4646%
# Epoch 27/30
# 26/26 - train_loss: 0.0310 - train_accuracy: 98.8757%                 - val_loss: 0.0008 - val_accuracy: 95.9596%
# Epoch 28/30
# 26/26 - train_loss: 0.0244 - train_accuracy: 99.2505%                 - val_loss: 0.0004 - val_accuracy: 96.9697%
# Epoch 29/30
# 26/26 - train_loss: 0.0248 - train_accuracy: 99.0006%                 - val_loss: 0.0007 - val_accuracy: 97.4747%
# Epoch 30/30
# 26/26 - train_loss: 0.0221 - train_accuracy: 99.3129%                 - val_loss: 0.0004 - val_accuracy: 95.9596%
# Learning Rate: 1e-05, Dropout: 0.3, Num Layers: 6, Test Accuracy: 0.9701
# Epoch 1/30
# 26/26 - train_loss: 1.6730 - train_accuracy: 23.0481%                 - val_loss: 0.6410 - val_accuracy: 27.2727%
# Epoch 2/30
# 26/26 - train_loss: 1.6332 - train_accuracy: 27.2330%                 - val_loss: 0.6818 - val_accuracy: 41.9192%
# Epoch 3/30
# 26/26 - train_loss: 1.5441 - train_accuracy: 33.8538%                 - val_loss: 0.5907 - val_accuracy: 48.9899%
# Epoch 4/30
# 26/26 - train_loss: 1.2686 - train_accuracy: 53.8413%                 - val_loss: 0.3787 - val_accuracy: 71.7172%
# Epoch 5/30
# 26/26 - train_loss: 0.8701 - train_accuracy: 71.8301%                 - val_loss: 0.3097 - val_accuracy: 75.2525%
# Epoch 6/30
# 26/26 - train_loss: 0.6260 - train_accuracy: 78.5759%                 - val_loss: 0.0693 - val_accuracy: 83.8384%
# Epoch 7/30
# 26/26 - train_loss: 0.4508 - train_accuracy: 84.8844%                 - val_loss: 0.0720 - val_accuracy: 91.9192%
# Epoch 8/30
# 26/26 - train_loss: 0.3318 - train_accuracy: 89.3816%                 - val_loss: 0.0286 - val_accuracy: 91.9192%
# Epoch 9/30
# 26/26 - train_loss: 0.2724 - train_accuracy: 90.5684%                 - val_loss: 0.0532 - val_accuracy: 90.9091%
# Epoch 10/30
# 26/26 - train_loss: 0.1946 - train_accuracy: 93.5041%                 - val_loss: 0.0107 - val_accuracy: 92.9293%
# Epoch 11/30
# 26/26 - train_loss: 0.1533 - train_accuracy: 94.8157%                 - val_loss: 0.0124 - val_accuracy: 93.9394%
# Epoch 12/30
# 26/26 - train_loss: 0.1423 - train_accuracy: 94.9407%                 - val_loss: 0.0038 - val_accuracy: 94.4444%
# Epoch 13/30
# 26/26 - train_loss: 0.1096 - train_accuracy: 96.0650%                 - val_loss: 0.0032 - val_accuracy: 93.9394%
# Epoch 14/30
# 26/26 - train_loss: 0.0959 - train_accuracy: 96.6896%                 - val_loss: 0.0037 - val_accuracy: 93.9394%
# Epoch 15/30
# 26/26 - train_loss: 0.0981 - train_accuracy: 96.1274%                 - val_loss: 0.0017 - val_accuracy: 94.4444%
# Epoch 16/30
# 26/26 - train_loss: 0.1082 - train_accuracy: 97.0019%                 - val_loss: 0.0020 - val_accuracy: 93.9394%
# Epoch 17/30
# 26/26 - train_loss: 0.1704 - train_accuracy: 94.0662%                 - val_loss: 0.0029 - val_accuracy: 94.9495%
# Epoch 18/30
# 26/26 - train_loss: 0.0698 - train_accuracy: 97.2517%                 - val_loss: 0.0080 - val_accuracy: 95.9596%
# Epoch 19/30
# 26/26 - train_loss: 0.0749 - train_accuracy: 97.6265%                 - val_loss: 0.0088 - val_accuracy: 94.9495%
# Epoch 20/30
# 26/26 - train_loss: 0.0854 - train_accuracy: 97.0019%                 - val_loss: 0.0009 - val_accuracy: 94.9495%
# Epoch 21/30
# 26/26 - train_loss: 0.0468 - train_accuracy: 98.3136%                 - val_loss: 0.0014 - val_accuracy: 95.9596%
# Epoch 22/30
# 26/26 - train_loss: 0.0399 - train_accuracy: 98.5009%                 - val_loss: 0.0899 - val_accuracy: 93.4343%
# Epoch 23/30
# 26/26 - train_loss: 0.0422 - train_accuracy: 98.5634%                 - val_loss: 0.0004 - val_accuracy: 95.9596%
# Epoch 24/30
# 26/26 - train_loss: 0.0470 - train_accuracy: 97.9388%                 - val_loss: 0.0041 - val_accuracy: 95.9596%
# Epoch 25/30
# 26/26 - train_loss: 0.0289 - train_accuracy: 99.0631%                 - val_loss: 0.0117 - val_accuracy: 94.9495%
# Epoch 26/30
# 26/26 - train_loss: 0.0244 - train_accuracy: 99.1255%                 - val_loss: 0.0008 - val_accuracy: 96.4646%
# Epoch 27/30
# 26/26 - train_loss: 0.0313 - train_accuracy: 98.9382%                 - val_loss: 0.0022 - val_accuracy: 96.4646%
# Epoch 28/30
# 26/26 - train_loss: 0.0437 - train_accuracy: 98.2511%                 - val_loss: 0.0004 - val_accuracy: 96.9697%
# Epoch 29/30
# 26/26 - train_loss: 0.0132 - train_accuracy: 99.8126%                 - val_loss: 0.0003 - val_accuracy: 96.4646%
# Epoch 30/30
# 26/26 - train_loss: 0.0096 - train_accuracy: 99.8751%                 - val_loss: 0.0003 - val_accuracy: 96.4646%
# Learning Rate: 1e-05, Dropout: 0.3, Num Layers: 12, Test Accuracy: 0.9652
# Best Model Accuracy: 0.9801
# Best Hyperparameters: {'lr': 0.0001, 'dropout': 0.2, 'num_layers': 6}
# <ipython-input-24-803cae586299>:41: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   best_model.load_state_dict(torch.load('best_model.pth'))
# Best Model Test Accuracy: 0.9801

# %% [markdown]
# # Give your answer here.
#
# (i) What is your best model?
#
# The best model is a TransformerClassifier with the following hyperparameters:
#
# {'lr': 0.0001, 'dropout': 0.2, 'num_layers': 6}
#
#
# (ii) The accuracy of your best model on the validation set
#
# 0.9801
#
#
# (iii) The values of the hyperparameters of your best model
#
# Optimizer: Adam
# Laerning rate: 0.0001
# Dropout: 0.2
# Num of layers = 6
# Embed dim = 512
# Num heads = 8
# FF dim = 2048
#
#
# (iv) The link to download your best model
#
# https://drive.google.com/file/d/1CenjILDZWOa012FtSspqDb1WpREcICLQ/view?usp=sharing

# %% [markdown]
# To run best model:

# %%
# Install gdown to download from Google Drive
# !pip install gdown

# Download the model file from Google Drive
# !gdown --id '1CenjILDZWOa012FtSspqDb1WpREcICLQ'

downloaded_model_path = "best_model.pth"

# Initialize the model with the best hyperparameters
best_hyperparameters = {'lr': 0.0001, 'dropout': 0.2, 'num_layers': 6}
transformer = TransformerClassifier(
    embed_dim=512,
    num_heads=8,
    ff_dim=2048,
    num_layers=best_hyperparameters['num_layers'],
    dropout_rate=best_hyperparameters['dropout'],
    data_manager=dm
)
transformer.build()
transformer.load_state_dict(torch.load(downloaded_model_path))
transformer = transformer.to(device)

# Evaluate the model on the test set
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(transformer.parameters(), lr=best_hyperparameters['lr'], betas=(0.9, 0.98), eps=1e-9)
trainer = BaseTrainer(model=transformer, criterion=criterion, optimizer=optimizer, train_loader=dm.train_loader, val_loader=dm.valid_loader)
test_loss, test_accuracy = trainer.evaluate(dm.test_loader)

print(f"Test Accuracy of the Best Model: {test_accuracy:.4f}")
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.16.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1CenjILDZWOa012FtSspqDb1WpREcICLQ
# From (redirected): https://drive.google.com/uc?id=1CenjILDZWOa012FtSspqDb1WpREcICLQ&confirm=t&uuid=4f32df4c-c5a2-4083-9c37-76cd3e876aef
# To: /content/best_model.pth
# 100% 138M/138M [00:00<00:00, 193MB/s]
# <ipython-input-27-2afa65424cc6>:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   transformer.load_state_dict(torch.load(downloaded_model_path))
# Test Accuracy of the Best Model: 0.9801

# %% [markdown]
# ---
# <div style="text-align: center"> <font color="green">GOOD LUCK WITH YOUR ASSIGNMENT 2!</font> </div>
# <div style="text-align: center"> <font color="black">END OF ASSIGNMENT</font> </div>
